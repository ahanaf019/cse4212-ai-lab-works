# %% [markdown]
# # CSE4212: Artificail Intelligence Lab
# ### **Date:** 8 March, 2024
#
# ## Group 2:
#
# - Nazmus Shakib
#
#   **ID:** 1910876105
#
#   **Session:** 2018-19
#
# - Md. Ahanaf Arif Khan
#
#   **ID:** 1910676110
#
#   **Session:** 2018-19
#
# - Farjana Aktar,
#
#   **ID:** 1912276145
#
#   **Session:** 2018-19
#
# - Mohammad Ashif,
#
#   **ID:** 1711076147
#
#   **Session:** 2016-17

# %% [markdown]
# # Assignment 4 UPDATE(Group-wise submission)
# Write a report on your binary classifier trained and tested using your private data collected by your mobile-phone cameras/conventional cameras/ laptop web cameras. Report should be submitted in PDF format prepared by Latex.
#
# Report should include as many analysis as possible about the results, procedure of tuning hyper-parameters to get better results.
#
# In order to avoid same image classes, groups are requested to entry their image class in the following sheet:
# https://docs.google.com/spreadsheets/d/1Ul_UZ306WAcCpnY2pwcs0C1JLrV-iNkuKSWGX1GXAjQ/edit?usp=sharing
# Each group needs to collect at least 400 images per class.
#
# Group need to build, train and test both a fully connected neural network-based binary classifier and convolutional neural network based binary classifier.

# %% [markdown]
# # Mount Google Drive
#
# Our dataset is stored in Google Drive. So, we need to mount drive first in order to load the dataset.

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# # Import Dependencies

# %%
import tensorflow as tf
from tensorflow import keras
from keras import Input, Model
from keras.layers import Dense, Flatten, Conv2D, MaxPooling2D
from keras.optimizers import Adam
from keras.losses import CategoricalCrossentropy, BinaryCrossentropy
from keras.metrics import CategoricalAccuracy, BinaryAccuracy, Precision, Recall, F1Score
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.applications import vgg16
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
# Out:
# 2024-03-16 08:47:04.691380: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-03-16 08:47:05.310357: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-16 08:47:05.310412: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-16 08:47:05.411648: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-16 08:47:05.634638: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-16 08:47:06.811381: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# # Hyper-Parameters

# %%
batch_size = 32
image_size = (32, 32)
learning_rate = 1e-4
epochs = 30
label_mode = 'int'

# %% [markdown]
# # Loading the Dataset

# %% [markdown]
# The dataset is stored as a zip file in google drive. First, we need to extract it.

# %%
dataset_base_path = './'
db_name = 'dataset_256'
# !unzip -o -q '{dataset_base_path}/{db_name}'

# %% [markdown]
# Create a dataset object for train, validation and test datasets respectively.

# %%
train_ds = keras.utils.image_dataset_from_directory(
    f'{db_name}/train',
    image_size=image_size,
    batch_size=batch_size,
    label_mode=label_mode,
    shuffle=True
)

val_ds = keras.utils.image_dataset_from_directory(
    f'{db_name}/valid',
    image_size=image_size,
    batch_size=batch_size,
    label_mode=label_mode,
    shuffle=False
)

test_ds = keras.utils.image_dataset_from_directory(
    f'{db_name}/test',
    image_size=image_size,
    batch_size=batch_size,
    label_mode=label_mode,
    shuffle=False
)

# Used for plotting
class_names = train_ds.class_names

test_ds = test_ds.map(lambda x, y: (x, tf.cast(y, tf.float32)))
# Out:
# Found 782 files belonging to 2 classes.
# Found 106 files belonging to 2 classes.
# Found 160 files belonging to 2 classes.

# %% [markdown]
# # Plot Samples from the Dataset

# %% [markdown]
# Our dataset contains images of books and notebooks. The images are of  resolution 32 x 32 pixels. Let us view a few samples from the dataset.

# %%
for imgs, labels in train_ds:
  break

mpl.rcParams['font.family'] = 'serif'
mpl.rcParams['font.size'] = '18'


plt.figure(figsize=(10, 10))
plt.suptitle('Samples from our Dataset')
for i in range(16):
  plt.subplot(4,4,i+1)
  plt.imshow(imgs[i] / 255)
  plt.axis('off')
  plt.title(class_names[labels[i]])
plt.show();

# %% [markdown]
# # Fully Connected Network

# %% [markdown]
# ### Create the Model and View Summary

# %%
inputs = Input(shape=image_size + (3,))
x = Flatten()(inputs)
x = Dense(256, activation='relu')(x)
x = Dense(512, activation='relu')(x)
x = Dense(512, activation='relu')(x)
x = Dense(128, activation='relu')(x)
x = Dense(128, activation='relu')(x)
outputs = Dense(1, activation='sigmoid')(x)

fc_model = keras.Model(inputs, outputs, name='FC_Model')
fc_model.summary()
# Out:
# Model: "FC_Model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  flatten_3 (Flatten)         (None, 3072)              0
#
#  dense_12 (Dense)            (None, 256)               786688
#
#  dense_13 (Dense)            (None, 512)               131584
#
#  dense_14 (Dense)            (None, 512)               262656
#
#  dense_15 (Dense)            (None, 128)               65664
#
#  dense_16 (Dense)            (None, 128)               16512
#
#  dense_17 (Dense)            (None, 1)                 129
#
# =================================================================
# Total params: 1263233 (4.82 MB)
# Trainable params: 1263233 (4.82 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Compile and Fit the model

# %%
fc_model.compile(
    optimizer=Adam(learning_rate=learning_rate),
    loss=BinaryCrossentropy(),
    metrics=[BinaryAccuracy(name='accuracy')]
)

history = fc_model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=epochs,
    callbacks=[
        ModelCheckpoint('fc_model.keras', save_weights_only=False, save_best_only=True, verbose=1),
    ],
)
# Out:
# Epoch 1/30
# 19/25 [=====================>........] - ETA: 0s - loss: 5.9825 - accuracy: 0.5724
# Epoch 1: val_loss improved from inf to 1.77856, saving model to fc_model.keras
# 25/25 [==============================] - 1s 9ms/step - loss: 5.1189 - accuracy: 0.5882 - val_loss: 1.7786 - val_accuracy: 0.6698
# Epoch 2/30
# 16/25 [==================>...........] - ETA: 0s - loss: 1.6949 - accuracy: 0.6621
# Epoch 2: val_loss improved from 1.77856 to 1.25262, saving model to fc_model.keras
# 25/25 [==============================] - 0s 6ms/step - loss: 1.5216 - accuracy: 0.6611 - val_loss: 1.2526 - val_accuracy: 0.6509
# Epoch 3/30
# 18/25 [====================>.........] - ETA: 0s - loss: 0.9107 - accuracy: 0.7049
# Epoch 3: val_loss improved from 1.25262 to 1.21677, saving model to fc_model.keras
# 25/25 [==============================] - 0s 6ms/step - loss: 0.9015 - accuracy: 0.7110 - val_loss: 1.2168 - val_accuracy: 0.6509
# Epoch 4/30
# 21/25 [========================>.....] - ETA: 0s - loss: 0.9252 - accuracy: 0.7321
# Epoch 4: val_loss did not improve from 1.21677
# 25/25 [==============================] - 0s 4ms/step - loss: 0.9212 - accuracy: 0.7366 - val_loss: 1.6671 - val_accuracy: 0.5849
# Epoch 5/30
# 13/25 [==============>...............] - ETA: 0s - loss: 0.6788 - accuracy: 0.7524
# Epoch 5: val_loss did not improve from 1.21677
# 25/25 [==============================] - 0s 4ms/step - loss: 0.6092 - accuracy: 0.7711 - val_loss: 1.4461 - val_accuracy: 0.5943
# Epoch 6/30
#  8/25 [========>.....................] - ETA: 0s - loss: 0.3500 - accuracy: 0.8477
# Epoch 6: val_loss did not improve from 1.21677
# 25/25 [==============================] - 0s 5ms/step - loss: 0.3325 - accuracy: 0.8593 - val_loss: 1.2964 - val_accuracy: 0.6132
# Epoch 7/30
# 16/25 [==================>...........] - ETA: 0s - loss: 0.1990 - accuracy: 0.9082
# Epoch 7: val_loss did not improve from 1.21677
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2290 - accuracy: 0.9003 - val_loss: 1.2921 - val_accuracy: 0.5755
# Epoch 8/30
# 16/25 [==================>...........] - ETA: 0s - loss: 0.2064 - accuracy: 0.9160
# Epoch 8: val_loss improved from 1.21677 to 1.09777, saving model to fc_model.keras
# 25/25 [==============================] - 0s 6ms/step - loss: 0.2832 - accuracy: 0.8887 - val_loss: 1.0978 - val_accuracy: 0.5943
# Epoch 9/30
# 16/25 [==================>...........] - ETA: 0s - loss: 0.1858 - accuracy: 0.9160
# Epoch 9: val_loss did not improve from 1.09777
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2604 - accuracy: 0.8836 - val_loss: 1.1562 - val_accuracy: 0.5943
# Epoch 10/30
# 16/25 [==================>...........] - ETA: 0s - loss: 0.2730 - accuracy: 0.8848
# Epoch 10: val_loss improved from 1.09777 to 1.08087, saving model to fc_model.keras
# 25/25 [==============================] - 0s 5ms/step - loss: 0.2951 - accuracy: 0.8836 - val_loss: 1.0809 - val_accuracy: 0.6509
# Epoch 11/30
# 18/25 [====================>.........] - ETA: 0s - loss: 0.2266 - accuracy: 0.8941
# Epoch 11: val_loss did not improve from 1.08087
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2056 - accuracy: 0.9066 - val_loss: 1.3072 - val_accuracy: 0.6038
# Epoch 12/30
# 15/25 [=================>............] - ETA: 0s - loss: 0.1583 - accuracy: 0.9292
# Epoch 12: val_loss did not improve from 1.08087
# 25/25 [==============================] - 0s 4ms/step - loss: 0.1398 - accuracy: 0.9425 - val_loss: 1.2918 - val_accuracy: 0.6132
# Epoch 13/30
# 21/25 [========================>.....] - ETA: 0s - loss: 0.0933 - accuracy: 0.9658
# Epoch 13: val_loss did not improve from 1.08087
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0969 - accuracy: 0.9616 - val_loss: 1.1904 - val_accuracy: 0.6038
# Epoch 14/30
# 17/25 [===================>..........] - ETA: 0s - loss: 0.1074 - accuracy: 0.9577
# Epoch 14: val_loss did not improve from 1.08087
# 25/25 [==============================] - 0s 4ms/step - loss: 0.1010 - accuracy: 0.9655 - val_loss: 1.5413 - val_accuracy: 0.5849
# Epoch 15/30
# 20/25 [=======================>......] - ETA: 0s - loss: 0.1014 - accuracy: 0.9578
# Epoch 15: val_loss did not improve from 1.08087
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1019 - accuracy: 0.9578 - val_loss: 1.1294 - val_accuracy: 0.6792
# Epoch 16/30
# 21/25 [========================>.....] - ETA: 0s - loss: 0.1397 - accuracy: 0.9390
# Epoch 16: val_loss did not improve from 1.08087
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1320 - accuracy: 0.9450 - val_loss: 1.1089 - val_accuracy: 0.6132
# Epoch 17/30
# 18/25 [====================>.........] - ETA: 0s - loss: 0.0939 - accuracy: 0.9653
# Epoch 17: val_loss did not improve from 1.08087
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0825 - accuracy: 0.9706 - val_loss: 1.2778 - val_accuracy: 0.6415
# Epoch 18/30
# 15/25 [=================>............] - ETA: 0s - loss: 0.0644 - accuracy: 0.9812
# Epoch 18: val_loss did not improve from 1.08087
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0662 - accuracy: 0.9795 - val_loss: 1.3230 - val_accuracy: 0.6698
# Epoch 19/30
# 20/25 [=======================>......] - ETA: 0s - loss: 0.0860 - accuracy: 0.9688
# Epoch 19: val_loss did not improve from 1.08087
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0936 - accuracy: 0.9642 - val_loss: 1.2956 - val_accuracy: 0.6321
# Epoch 20/30
# 15/25 [=================>............] - ETA: 0s - loss: 0.0426 - accuracy: 0.9875
# Epoch 20: val_loss did not improve from 1.08087
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0601 - accuracy: 0.9783 - val_loss: 1.7047 - val_accuracy: 0.6226
# Epoch 21/30
# 23/25 [==========================>...] - ETA: 0s - loss: 0.1163 - accuracy: 0.9538
# Epoch 21: val_loss did not improve from 1.08087
# 25/25 [==============================] - 0s 9ms/step - loss: 0.1107 - accuracy: 0.9565 - val_loss: 1.2227 - val_accuracy: 0.6604
# Epoch 22/30
# 20/25 [=======================>......] - ETA: 0s - loss: 0.0601 - accuracy: 0.9812
# Epoch 22: val_loss did not improve from 1.08087
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0630 - accuracy: 0.9783 - val_loss: 1.2672 - val_accuracy: 0.6321
# Epoch 23/30
# 17/25 [===================>..........] - ETA: 0s - loss: 0.0579 - accuracy: 0.9779
# Epoch 23: val_loss did not improve from 1.08087
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0650 - accuracy: 0.9744 - val_loss: 1.6641 - val_accuracy: 0.6321
# Epoch 24/30
# 15/25 [=================>............] - ETA: 0s - loss: 0.1239 - accuracy: 0.9521
# Epoch 24: val_loss did not improve from 1.08087
# 25/25 [==============================] - 0s 4ms/step - loss: 0.1225 - accuracy: 0.9565 - val_loss: 1.6191 - val_accuracy: 0.6321
# Epoch 25/30
# 16/25 [==================>...........] - ETA: 0s - loss: 0.2784 - accuracy: 0.8965
# Epoch 25: val_loss did not improve from 1.08087
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3133 - accuracy: 0.8772 - val_loss: 2.7457 - val_accuracy: 0.5566
# Epoch 26/30
# 15/25 [=================>............] - ETA: 0s - loss: 0.9405 - accuracy: 0.7688
# Epoch 26: val_loss did not improve from 1.08087
# 25/25 [==============================] - 0s 4ms/step - loss: 0.7687 - accuracy: 0.7992 - val_loss: 1.7340 - val_accuracy: 0.6509
# Epoch 27/30
# 16/25 [==================>...........] - ETA: 0s - loss: 0.6386 - accuracy: 0.8086
# Epoch 27: val_loss did not improve from 1.08087
# 25/25 [==============================] - 0s 4ms/step - loss: 0.5547 - accuracy: 0.8248 - val_loss: 1.5297 - val_accuracy: 0.5472
# Epoch 28/30
# 20/25 [=======================>......] - ETA: 0s - loss: 0.8867 - accuracy: 0.7797
# Epoch 28: val_loss did not improve from 1.08087
# 25/25 [==============================] - 0s 4ms/step - loss: 0.8486 - accuracy: 0.7775 - val_loss: 1.5278 - val_accuracy: 0.5755
# Epoch 29/30
# 21/25 [========================>.....] - ETA: 0s - loss: 0.5387 - accuracy: 0.8304
# Epoch 29: val_loss did not improve from 1.08087
# 25/25 [==============================] - 0s 4ms/step - loss: 0.5454 - accuracy: 0.8286 - val_loss: 2.6615 - val_accuracy: 0.5755
# Epoch 30/30
# 21/25 [========================>.....] - ETA: 0s - loss: 0.4052 - accuracy: 0.8467
# Epoch 30: val_loss did not improve from 1.08087
# 25/25 [==============================] - 0s 3ms/step - loss: 0.3937 - accuracy: 0.8529 - val_loss: 1.4317 - val_accuracy: 0.6132

# %% [markdown]
# ### Plotting the loss and accuracy curves

# %%
plt.figure(figsize=(16, 6))
plt.subplot(1,2,1)
plt.plot(history.history['loss'], '.-')
plt.plot(history.history['val_loss'], '.-')
plt.xlabel('Epoch')
plt.ylabel('Loss Value')
plt.legend(['loss', 'val_loss'])

plt.subplot(1,2,2)
plt.plot(history.history['accuracy'], '.-')
plt.plot(history.history['val_accuracy'], '.-')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.legend(['accuracy', 'val_accuracy'])

plt.show()

# %% [markdown]
# ### Loading the best checkpoint and evaluating model using the test dataset

# %%
fc_model = keras.models.load_model('fc_model.keras')

fc_model.compile(
    optimizer=Adam(learning_rate=learning_rate),
    loss=BinaryCrossentropy(),
    metrics=[
        BinaryAccuracy(name='accuracy'),
        Precision(name='precision'),
        Recall(name='recall'),
        F1Score(name='f1score'),
    ]
)

eval = fc_model.evaluate(test_ds, return_dict=True)

eval
# Out:
# 5/5 [==============================] - 1s 2ms/step - loss: 1.4020 - accuracy: 0.5250 - precision: 0.5417 - recall: 0.4756 - f1score: 0.6777
# {'loss': 1.4019920825958252,
#  'accuracy': 0.5249999761581421,
#  'precision': 0.5416666865348816,
#  'recall': 0.47560974955558777,
#  'f1score': array([0.6776859], dtype=float32)}

# %% [markdown]
# # Simple CNN

# %% [markdown]
# ### Create the Simple CNN Model and View Summary

# %%
inputs = Input(shape=image_size + (3,))
x = Conv2D(filters=128, kernel_size=3, padding='same', activation='relu')(inputs)
x = Conv2D(filters=128, kernel_size=3, padding='same', activation='relu')(x)
x = MaxPooling2D()(x)

x = Conv2D(filters=256, kernel_size=3, padding='same', activation='relu')(x)
x = Conv2D(filters=256, kernel_size=3, padding='same', activation='relu')(x)
x = MaxPooling2D()(x)

x = Conv2D(filters=512, kernel_size=3, padding='same', activation='relu')(x)
x = Conv2D(filters=512, kernel_size=3, padding='same', activation='relu')(x)
x = MaxPooling2D()(x)

x = Conv2D(filters=512, kernel_size=3, padding='same', activation='relu')(x)
x = Conv2D(filters=512, kernel_size=3, padding='same', activation='relu')(x)
x = MaxPooling2D()(x)

x = Flatten()(x)
x = Dense(128, activation='relu')(x)
x = Dense(32, activation='relu')(x)
outputs = Dense(1, activation='sigmoid')(x)

scnn_model = keras.Model(inputs, outputs, name='SCNN_Model')
scnn_model.summary()
# Out:
# Model: "SCNN_Model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  conv2d_8 (Conv2D)           (None, 32, 32, 128)       3584
#
#  conv2d_9 (Conv2D)           (None, 32, 32, 128)       147584
#
#  max_pooling2d_4 (MaxPoolin  (None, 16, 16, 128)       0
#  g2D)
#
#  conv2d_10 (Conv2D)          (None, 16, 16, 256)       295168
#
#  conv2d_11 (Conv2D)          (None, 16, 16, 256)       590080
#
#  max_pooling2d_5 (MaxPoolin  (None, 8, 8, 256)         0
#  g2D)
#
#  conv2d_12 (Conv2D)          (None, 8, 8, 512)         1180160
#
#  conv2d_13 (Conv2D)          (None, 8, 8, 512)         2359808
#
#  max_pooling2d_6 (MaxPoolin  (None, 4, 4, 512)         0
#  g2D)
#
#  conv2d_14 (Conv2D)          (None, 4, 4, 512)         2359808
#
#  conv2d_15 (Conv2D)          (None, 4, 4, 512)         2359808
#
#  max_pooling2d_7 (MaxPoolin  (None, 2, 2, 512)         0
#  g2D)
#
#  flatten_4 (Flatten)         (None, 2048)              0
#
#  dense_18 (Dense)            (None, 128)               262272
#
#  dense_19 (Dense)            (None, 32)                4128
#
#  dense_20 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 9562433 (36.48 MB)
# Trainable params: 9562433 (36.48 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Compile and Fit the model

# %%
scnn_model.compile(
    optimizer=Adam(learning_rate=learning_rate),
    loss=BinaryCrossentropy(),
    metrics=[BinaryAccuracy(name='accuracy')]
)

history = scnn_model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=epochs,
    callbacks=[
        ModelCheckpoint('scnn_model.keras', save_weights_only=False, save_best_only=True, verbose=1),
    ],
)
# Out:
# Epoch 1/30
# 25/25 [==============================] - ETA: 0s - loss: 0.7670 - accuracy: 0.5818
# Epoch 1: val_loss improved from inf to 0.69208, saving model to scnn_model.keras
# 25/25 [==============================] - 3s 30ms/step - loss: 0.7670 - accuracy: 0.5818 - val_loss: 0.6921 - val_accuracy: 0.5566
# Epoch 2/30
# 25/25 [==============================] - ETA: 0s - loss: 0.6109 - accuracy: 0.6854
# Epoch 2: val_loss improved from 0.69208 to 0.64722, saving model to scnn_model.keras
# 25/25 [==============================] - 1s 26ms/step - loss: 0.6109 - accuracy: 0.6854 - val_loss: 0.6472 - val_accuracy: 0.6038
# Epoch 3/30
# 23/25 [==========================>...] - ETA: 0s - loss: 0.5394 - accuracy: 0.7391
# Epoch 3: val_loss improved from 0.64722 to 0.62216, saving model to scnn_model.keras
# 25/25 [==============================] - 1s 27ms/step - loss: 0.5393 - accuracy: 0.7340 - val_loss: 0.6222 - val_accuracy: 0.5943
# Epoch 4/30
# 25/25 [==============================] - ETA: 0s - loss: 0.4830 - accuracy: 0.7647
# Epoch 4: val_loss improved from 0.62216 to 0.62098, saving model to scnn_model.keras
# 25/25 [==============================] - 1s 26ms/step - loss: 0.4830 - accuracy: 0.7647 - val_loss: 0.6210 - val_accuracy: 0.6604
# Epoch 5/30
# 25/25 [==============================] - ETA: 0s - loss: 0.3421 - accuracy: 0.8568
# Epoch 5: val_loss did not improve from 0.62098
# 25/25 [==============================] - 0s 16ms/step - loss: 0.3421 - accuracy: 0.8568 - val_loss: 0.7097 - val_accuracy: 0.6887
# Epoch 6/30
# 24/25 [===========================>..] - ETA: 0s - loss: 0.3447 - accuracy: 0.8685
# Epoch 6: val_loss improved from 0.62098 to 0.61958, saving model to scnn_model.keras
# 25/25 [==============================] - 1s 29ms/step - loss: 0.3456 - accuracy: 0.8683 - val_loss: 0.6196 - val_accuracy: 0.6604
# Epoch 7/30
# 25/25 [==============================] - ETA: 0s - loss: 0.2558 - accuracy: 0.9054
# Epoch 7: val_loss did not improve from 0.61958
# 25/25 [==============================] - 0s 16ms/step - loss: 0.2558 - accuracy: 0.9054 - val_loss: 0.8808 - val_accuracy: 0.6321
# Epoch 8/30
# 23/25 [==========================>...] - ETA: 0s - loss: 0.2290 - accuracy: 0.8940
# Epoch 8: val_loss did not improve from 0.61958
# 25/25 [==============================] - 0s 17ms/step - loss: 0.2270 - accuracy: 0.8951 - val_loss: 0.9267 - val_accuracy: 0.6604
# Epoch 9/30
# 25/25 [==============================] - ETA: 0s - loss: 0.1238 - accuracy: 0.9565
# Epoch 9: val_loss did not improve from 0.61958
# 25/25 [==============================] - 0s 16ms/step - loss: 0.1238 - accuracy: 0.9565 - val_loss: 1.0877 - val_accuracy: 0.6226
# Epoch 10/30
# 23/25 [==========================>...] - ETA: 0s - loss: 0.0815 - accuracy: 0.9783
# Epoch 10: val_loss did not improve from 0.61958
# 25/25 [==============================] - 0s 16ms/step - loss: 0.0804 - accuracy: 0.9783 - val_loss: 1.1439 - val_accuracy: 0.6887
# Epoch 11/30
# 24/25 [===========================>..] - ETA: 0s - loss: 0.0544 - accuracy: 0.9844
# Epoch 11: val_loss did not improve from 0.61958
# 25/25 [==============================] - 0s 16ms/step - loss: 0.0550 - accuracy: 0.9847 - val_loss: 1.1579 - val_accuracy: 0.7264
# Epoch 12/30
# 25/25 [==============================] - ETA: 0s - loss: 0.0890 - accuracy: 0.9629
# Epoch 12: val_loss did not improve from 0.61958
# 25/25 [==============================] - 0s 16ms/step - loss: 0.0890 - accuracy: 0.9629 - val_loss: 0.9473 - val_accuracy: 0.7170
# Epoch 13/30
# 25/25 [==============================] - ETA: 0s - loss: 0.0489 - accuracy: 0.9859
# Epoch 13: val_loss did not improve from 0.61958
# 25/25 [==============================] - 0s 15ms/step - loss: 0.0489 - accuracy: 0.9859 - val_loss: 1.0903 - val_accuracy: 0.7264
# Epoch 14/30
# 25/25 [==============================] - ETA: 0s - loss: 0.0477 - accuracy: 0.9821
# Epoch 14: val_loss did not improve from 0.61958
# 25/25 [==============================] - 0s 16ms/step - loss: 0.0477 - accuracy: 0.9821 - val_loss: 1.4158 - val_accuracy: 0.7170
# Epoch 15/30
# 24/25 [===========================>..] - ETA: 0s - loss: 0.0625 - accuracy: 0.9883
# Epoch 15: val_loss did not improve from 0.61958
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0614 - accuracy: 0.9885 - val_loss: 1.0865 - val_accuracy: 0.7075
# Epoch 16/30
# 25/25 [==============================] - ETA: 0s - loss: 0.0135 - accuracy: 0.9987
# Epoch 16: val_loss did not improve from 0.61958
# 25/25 [==============================] - 0s 16ms/step - loss: 0.0135 - accuracy: 0.9987 - val_loss: 1.6066 - val_accuracy: 0.6698
# Epoch 17/30
# 25/25 [==============================] - ETA: 0s - loss: 0.0083 - accuracy: 0.9987
# Epoch 17: val_loss did not improve from 0.61958
# 25/25 [==============================] - 0s 16ms/step - loss: 0.0083 - accuracy: 0.9987 - val_loss: 1.6198 - val_accuracy: 0.6981
# Epoch 18/30
# 25/25 [==============================] - ETA: 0s - loss: 0.0052 - accuracy: 0.9987
# Epoch 18: val_loss did not improve from 0.61958
# 25/25 [==============================] - 0s 16ms/step - loss: 0.0052 - accuracy: 0.9987 - val_loss: 1.8140 - val_accuracy: 0.6509
# Epoch 19/30
# 23/25 [==========================>...] - ETA: 0s - loss: 0.0032 - accuracy: 1.0000
# Epoch 19: val_loss did not improve from 0.61958
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 1.7175 - val_accuracy: 0.6792
# Epoch 20/30
# 21/25 [========================>.....] - ETA: 0s - loss: 0.0016 - accuracy: 1.0000
# Epoch 20: val_loss did not improve from 0.61958
# 25/25 [==============================] - 0s 15ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 2.0833 - val_accuracy: 0.6604
# Epoch 21/30
# 25/25 [==============================] - ETA: 0s - loss: 5.9313e-04 - accuracy: 1.0000
# Epoch 21: val_loss did not improve from 0.61958
# 25/25 [==============================] - 0s 16ms/step - loss: 5.9313e-04 - accuracy: 1.0000 - val_loss: 1.8702 - val_accuracy: 0.6887
# Epoch 22/30
# 25/25 [==============================] - ETA: 0s - loss: 2.8805e-04 - accuracy: 1.0000
# Epoch 22: val_loss did not improve from 0.61958
# 25/25 [==============================] - 0s 16ms/step - loss: 2.8805e-04 - accuracy: 1.0000 - val_loss: 1.9491 - val_accuracy: 0.6887
# Epoch 23/30
# 25/25 [==============================] - ETA: 0s - loss: 2.2613e-04 - accuracy: 1.0000
# Epoch 23: val_loss did not improve from 0.61958
# 25/25 [==============================] - 0s 16ms/step - loss: 2.2613e-04 - accuracy: 1.0000 - val_loss: 1.9924 - val_accuracy: 0.6792
# Epoch 24/30
# 22/25 [=========================>....] - ETA: 0s - loss: 1.9879e-04 - accuracy: 1.0000
# Epoch 24: val_loss did not improve from 0.61958
# 25/25 [==============================] - 0s 18ms/step - loss: 1.9350e-04 - accuracy: 1.0000 - val_loss: 2.0109 - val_accuracy: 0.6887
# Epoch 25/30
# 25/25 [==============================] - ETA: 0s - loss: 1.7153e-04 - accuracy: 1.0000
# Epoch 25: val_loss did not improve from 0.61958
# 25/25 [==============================] - 0s 16ms/step - loss: 1.7153e-04 - accuracy: 1.0000 - val_loss: 2.0306 - val_accuracy: 0.6887
# Epoch 26/30
# 25/25 [==============================] - ETA: 0s - loss: 1.5525e-04 - accuracy: 1.0000
# Epoch 26: val_loss did not improve from 0.61958
# 25/25 [==============================] - 0s 16ms/step - loss: 1.5525e-04 - accuracy: 1.0000 - val_loss: 2.0548 - val_accuracy: 0.6792
# Epoch 27/30
# 25/25 [==============================] - ETA: 0s - loss: 1.4473e-04 - accuracy: 1.0000
# Epoch 27: val_loss did not improve from 0.61958
# 25/25 [==============================] - 0s 16ms/step - loss: 1.4473e-04 - accuracy: 1.0000 - val_loss: 2.0639 - val_accuracy: 0.6887
# Epoch 28/30
# 25/25 [==============================] - ETA: 0s - loss: 1.2823e-04 - accuracy: 1.0000
# Epoch 28: val_loss did not improve from 0.61958
# 25/25 [==============================] - 0s 16ms/step - loss: 1.2823e-04 - accuracy: 1.0000 - val_loss: 2.0798 - val_accuracy: 0.6792
# Epoch 29/30
# 24/25 [===========================>..] - ETA: 0s - loss: 1.2003e-04 - accuracy: 1.0000
# Epoch 29: val_loss did not improve from 0.61958
# 25/25 [==============================] - 0s 16ms/step - loss: 1.1839e-04 - accuracy: 1.0000 - val_loss: 2.0926 - val_accuracy: 0.6887
# Epoch 30/30
# 25/25 [==============================] - ETA: 0s - loss: 1.1109e-04 - accuracy: 1.0000
# Epoch 30: val_loss did not improve from 0.61958
# 25/25 [==============================] - 0s 16ms/step - loss: 1.1109e-04 - accuracy: 1.0000 - val_loss: 2.1066 - val_accuracy: 0.6887

# %% [markdown]
# ### Plotting the loss and accuracy curves

# %%
plt.figure(figsize=(16, 6))
plt.subplot(1,2,1)
plt.plot(history.history['loss'], '.-')
plt.plot(history.history['val_loss'], '.-')
plt.xlabel('Epoch')
plt.ylabel('Loss Value')
plt.legend(['loss', 'val_loss'])

plt.subplot(1,2,2)
plt.plot(history.history['accuracy'], '.-')
plt.plot(history.history['val_accuracy'], '.-')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.legend(['accuracy', 'val_accuracy'])

plt.show()

# %% [markdown]
# ### Loading the best checkpoint and evaluating using the test dataset

# %%
scnn_model = keras.models.load_model('scnn_model.keras')

scnn_model.compile(
    optimizer=Adam(learning_rate=learning_rate),
    loss=BinaryCrossentropy(),
    metrics=[
        BinaryAccuracy(name='accuracy'),
        Precision(name='precision'),
        Recall(name='recall'),
        F1Score(name='f1score'),
    ]
)

eval = scnn_model.evaluate(test_ds, return_dict=True)

eval
# Out:
# 5/5 [==============================] - 0s 6ms/step - loss: 0.6641 - accuracy: 0.6562 - precision: 0.7077 - recall: 0.5610 - f1score: 0.6777
# {'loss': 0.664068341255188,
#  'accuracy': 0.65625,
#  'precision': 0.7076923251152039,
#  'recall': 0.5609756112098694,
#  'f1score': array([0.6776859], dtype=float32)}

# %% [markdown]
# # VGG16 Model With Randomlly Initialized Weights

# %% [markdown]
# ### Creating the VGG16 Model and Viewing its Summary

# %%
vgg16_model = vgg16.VGG16(include_top=False, weights=None, input_shape=image_size+(3,))

inputs = vgg16_model.input
x = Flatten()(vgg16_model.output)
x = Dense(256, activation='relu')(x)
x = Dense(128, activation='relu')(x)
outputs = Dense(1, activation='sigmoid')(x)

vgg16_model = keras.Model(inputs, outputs, name='VGG16_Model')
vgg16_model.summary()
# Out:
# Model: "VGG16_Model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  block1_conv1 (Conv2D)       (None, 32, 32, 64)        1792
#
#  block1_conv2 (Conv2D)       (None, 32, 32, 64)        36928
#
#  block1_pool (MaxPooling2D)  (None, 16, 16, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 16, 16, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 16, 16, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 8, 8, 128)         0
#
#  block3_conv1 (Conv2D)       (None, 8, 8, 256)         295168
#
#  block3_conv2 (Conv2D)       (None, 8, 8, 256)         590080
#
#  block3_conv3 (Conv2D)       (None, 8, 8, 256)         590080
#
#  block3_pool (MaxPooling2D)  (None, 4, 4, 256)         0
#
#  block4_conv1 (Conv2D)       (None, 4, 4, 512)         1180160
#
#  block4_conv2 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  block4_conv3 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  block4_pool (MaxPooling2D)  (None, 2, 2, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 2, 2, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 2, 2, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 2, 2, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 1, 1, 512)         0
#
#  flatten_5 (Flatten)         (None, 512)               0
#
#  dense_21 (Dense)            (None, 256)               131328
#
#  dense_22 (Dense)            (None, 128)               32896
#
#  dense_23 (Dense)            (None, 1)                 129
#
# =================================================================
# Total params: 14879041 (56.76 MB)
# Trainable params: 14879041 (56.76 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Compile and Fit the Model

# %%
vgg16_model.compile(
    optimizer=Adam(learning_rate=learning_rate),
    loss=BinaryCrossentropy(),
    metrics=[BinaryAccuracy(name='accuracy')]
)

history = vgg16_model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=epochs,
    callbacks=[
        ModelCheckpoint('vgg16_model-noTL.keras', save_weights_only=False, save_best_only=True, verbose=1),
    ],
)
# Out:
# Epoch 1/30
# 25/25 [==============================] - ETA: 0s - loss: 0.6981 - accuracy: 0.5281
# Epoch 1: val_loss improved from inf to 0.69028, saving model to vgg16_model-noTL.keras
# 25/25 [==============================] - 4s 38ms/step - loss: 0.6981 - accuracy: 0.5281 - val_loss: 0.6903 - val_accuracy: 0.5849
# Epoch 2/30
# 25/25 [==============================] - ETA: 0s - loss: 0.6816 - accuracy: 0.5460
# Epoch 2: val_loss did not improve from 0.69028
# 25/25 [==============================] - 0s 16ms/step - loss: 0.6816 - accuracy: 0.5460 - val_loss: 0.7042 - val_accuracy: 0.4811
# Epoch 3/30
# 24/25 [===========================>..] - ETA: 0s - loss: 0.6699 - accuracy: 0.5651
# Epoch 3: val_loss improved from 0.69028 to 0.66353, saving model to vgg16_model-noTL.keras
# 25/25 [==============================] - 1s 31ms/step - loss: 0.6697 - accuracy: 0.5665 - val_loss: 0.6635 - val_accuracy: 0.5660
# Epoch 4/30
# 25/25 [==============================] - ETA: 0s - loss: 0.6043 - accuracy: 0.6650
# Epoch 4: val_loss did not improve from 0.66353
# 25/25 [==============================] - 0s 16ms/step - loss: 0.6043 - accuracy: 0.6650 - val_loss: 1.1902 - val_accuracy: 0.4811
# Epoch 5/30
# 23/25 [==========================>...] - ETA: 0s - loss: 0.6126 - accuracy: 0.6698
# Epoch 5: val_loss improved from 0.66353 to 0.64392, saving model to vgg16_model-noTL.keras
# 25/25 [==============================] - 1s 33ms/step - loss: 0.6111 - accuracy: 0.6714 - val_loss: 0.6439 - val_accuracy: 0.6132
# Epoch 6/30
# 25/25 [==============================] - ETA: 0s - loss: 0.4490 - accuracy: 0.7737
# Epoch 6: val_loss did not improve from 0.64392
# 25/25 [==============================] - 0s 17ms/step - loss: 0.4490 - accuracy: 0.7737 - val_loss: 0.6537 - val_accuracy: 0.6415
# Epoch 7/30
# 25/25 [==============================] - ETA: 0s - loss: 0.4136 - accuracy: 0.7890
# Epoch 7: val_loss did not improve from 0.64392
# 25/25 [==============================] - 0s 15ms/step - loss: 0.4136 - accuracy: 0.7890 - val_loss: 0.6560 - val_accuracy: 0.6981
# Epoch 8/30
# 23/25 [==========================>...] - ETA: 0s - loss: 0.4047 - accuracy: 0.8030
# Epoch 8: val_loss did not improve from 0.64392
# 25/25 [==============================] - 1s 20ms/step - loss: 0.4014 - accuracy: 0.8031 - val_loss: 0.6489 - val_accuracy: 0.6415
# Epoch 9/30
# 24/25 [===========================>..] - ETA: 0s - loss: 0.3110 - accuracy: 0.8555
# Epoch 9: val_loss did not improve from 0.64392
# 25/25 [==============================] - 0s 16ms/step - loss: 0.3084 - accuracy: 0.8568 - val_loss: 1.7515 - val_accuracy: 0.6226
# Epoch 10/30
# 25/25 [==============================] - ETA: 0s - loss: 0.2254 - accuracy: 0.9028
# Epoch 10: val_loss did not improve from 0.64392
# 25/25 [==============================] - 0s 16ms/step - loss: 0.2254 - accuracy: 0.9028 - val_loss: 1.3696 - val_accuracy: 0.6509
# Epoch 11/30
# 25/25 [==============================] - ETA: 0s - loss: 0.2165 - accuracy: 0.9066
# Epoch 11: val_loss did not improve from 0.64392
# 25/25 [==============================] - 0s 16ms/step - loss: 0.2165 - accuracy: 0.9066 - val_loss: 1.1158 - val_accuracy: 0.6132
# Epoch 12/30
# 25/25 [==============================] - ETA: 0s - loss: 0.1560 - accuracy: 0.9348
# Epoch 12: val_loss did not improve from 0.64392
# 25/25 [==============================] - 0s 16ms/step - loss: 0.1560 - accuracy: 0.9348 - val_loss: 1.4297 - val_accuracy: 0.6887
# Epoch 13/30
# 24/25 [===========================>..] - ETA: 0s - loss: 0.1237 - accuracy: 0.9453
# Epoch 13: val_loss did not improve from 0.64392
# 25/25 [==============================] - 0s 17ms/step - loss: 0.1228 - accuracy: 0.9463 - val_loss: 1.4196 - val_accuracy: 0.6698
# Epoch 14/30
# 25/25 [==============================] - ETA: 0s - loss: 0.0748 - accuracy: 0.9693
# Epoch 14: val_loss did not improve from 0.64392
# 25/25 [==============================] - 0s 16ms/step - loss: 0.0748 - accuracy: 0.9693 - val_loss: 1.2211 - val_accuracy: 0.7642
# Epoch 15/30
# 25/25 [==============================] - ETA: 0s - loss: 0.0474 - accuracy: 0.9847
# Epoch 15: val_loss did not improve from 0.64392
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0474 - accuracy: 0.9847 - val_loss: 1.7152 - val_accuracy: 0.7170
# Epoch 16/30
# 25/25 [==============================] - ETA: 0s - loss: 0.1058 - accuracy: 0.9604
# Epoch 16: val_loss did not improve from 0.64392
# 25/25 [==============================] - 0s 16ms/step - loss: 0.1058 - accuracy: 0.9604 - val_loss: 0.7831 - val_accuracy: 0.7170
# Epoch 17/30
# 25/25 [==============================] - ETA: 0s - loss: 0.0686 - accuracy: 0.9859
# Epoch 17: val_loss did not improve from 0.64392
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0686 - accuracy: 0.9859 - val_loss: 1.3678 - val_accuracy: 0.6698
# Epoch 18/30
# 22/25 [=========================>....] - ETA: 0s - loss: 0.0508 - accuracy: 0.9872
# Epoch 18: val_loss did not improve from 0.64392
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0542 - accuracy: 0.9847 - val_loss: 1.0955 - val_accuracy: 0.7453
# Epoch 19/30
# 25/25 [==============================] - ETA: 0s - loss: 0.0472 - accuracy: 0.9898
# Epoch 19: val_loss did not improve from 0.64392
# 25/25 [==============================] - 0s 16ms/step - loss: 0.0472 - accuracy: 0.9898 - val_loss: 1.9952 - val_accuracy: 0.6981
# Epoch 20/30
# 25/25 [==============================] - ETA: 0s - loss: 0.0458 - accuracy: 0.9847
# Epoch 20: val_loss did not improve from 0.64392
# 25/25 [==============================] - 0s 16ms/step - loss: 0.0458 - accuracy: 0.9847 - val_loss: 1.5455 - val_accuracy: 0.6698
# Epoch 21/30
# 24/25 [===========================>..] - ETA: 0s - loss: 0.0347 - accuracy: 0.9870
# Epoch 21: val_loss did not improve from 0.64392
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0352 - accuracy: 0.9859 - val_loss: 1.2885 - val_accuracy: 0.7642
# Epoch 22/30
# 24/25 [===========================>..] - ETA: 0s - loss: 0.0718 - accuracy: 0.9766
# Epoch 22: val_loss did not improve from 0.64392
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0706 - accuracy: 0.9770 - val_loss: 1.7288 - val_accuracy: 0.7075
# Epoch 23/30
# 25/25 [==============================] - ETA: 0s - loss: 0.0079 - accuracy: 0.9962
# Epoch 23: val_loss did not improve from 0.64392
# 25/25 [==============================] - 0s 16ms/step - loss: 0.0079 - accuracy: 0.9962 - val_loss: 2.5104 - val_accuracy: 0.7170
# Epoch 24/30
# 24/25 [===========================>..] - ETA: 0s - loss: 0.1162 - accuracy: 0.9688
# Epoch 24: val_loss did not improve from 0.64392
# 25/25 [==============================] - 0s 17ms/step - loss: 0.1155 - accuracy: 0.9680 - val_loss: 0.8231 - val_accuracy: 0.7358
# Epoch 25/30
# 25/25 [==============================] - ETA: 0s - loss: 0.0218 - accuracy: 0.9936
# Epoch 25: val_loss did not improve from 0.64392
# 25/25 [==============================] - 0s 16ms/step - loss: 0.0218 - accuracy: 0.9936 - val_loss: 2.1669 - val_accuracy: 0.7453
# Epoch 26/30
# 24/25 [===========================>..] - ETA: 0s - loss: 0.0770 - accuracy: 0.9727
# Epoch 26: val_loss did not improve from 0.64392
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0757 - accuracy: 0.9731 - val_loss: 1.3348 - val_accuracy: 0.7170
# Epoch 27/30
# 25/25 [==============================] - ETA: 0s - loss: 0.0244 - accuracy: 0.9936
# Epoch 27: val_loss did not improve from 0.64392
# 25/25 [==============================] - 0s 16ms/step - loss: 0.0244 - accuracy: 0.9936 - val_loss: 1.8998 - val_accuracy: 0.7170
# Epoch 28/30
# 25/25 [==============================] - ETA: 0s - loss: 0.0125 - accuracy: 0.9962
# Epoch 28: val_loss did not improve from 0.64392
# 25/25 [==============================] - 0s 16ms/step - loss: 0.0125 - accuracy: 0.9962 - val_loss: 2.1270 - val_accuracy: 0.7264
# Epoch 29/30
# 25/25 [==============================] - ETA: 0s - loss: 0.0018 - accuracy: 1.0000
# Epoch 29: val_loss did not improve from 0.64392
# 25/25 [==============================] - 0s 16ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 2.6729 - val_accuracy: 0.7075
# Epoch 30/30
# 25/25 [==============================] - ETA: 0s - loss: 5.0784e-04 - accuracy: 1.0000
# Epoch 30: val_loss did not improve from 0.64392
# 25/25 [==============================] - 0s 16ms/step - loss: 5.0784e-04 - accuracy: 1.0000 - val_loss: 2.7867 - val_accuracy: 0.7453

# %% [markdown]
# ### Plotting the loss and accuracy graphs

# %%
plt.figure(figsize=(16, 6))
plt.subplot(1,2,1)
plt.plot(history.history['loss'], '.-')
plt.plot(history.history['val_loss'], '.-')
plt.xlabel('Epoch')
plt.ylabel('Loss Value')
plt.legend(['loss', 'val_loss'])

plt.subplot(1,2,2)
plt.plot(history.history['accuracy'], '.-')
plt.plot(history.history['val_accuracy'], '.-')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1.1])
plt.legend(['accuracy', 'val_accuracy'])

plt.show()

# %% [markdown]
# ### Loading the best checkpoint and evaluating the model using the test dataset

# %%
vgg16_model = keras.models.load_model('vgg16_model-noTL.keras')

vgg16_model.compile(
    optimizer=Adam(learning_rate=learning_rate),
    loss=BinaryCrossentropy(),
    metrics=[
        BinaryAccuracy(name='accuracy'),
        Precision(name='precision'),
        Recall(name='recall'),
        F1Score(name='f1score'),
    ]
)

eval = vgg16_model.evaluate(test_ds, return_dict=True)

eval
# Out:
# 5/5 [==============================] - 0s 11ms/step - loss: 0.6172 - accuracy: 0.6438 - precision: 0.7273 - recall: 0.4878 - f1score: 0.6777
# {'loss': 0.6172350645065308,
#  'accuracy': 0.643750011920929,
#  'precision': 0.7272727489471436,
#  'recall': 0.4878048896789551,
#  'f1score': array([0.6776859], dtype=float32)}

# %% [markdown]
# # Result Analysis

# %% [markdown]
# Gathering all the test labels inside a list

# %%
labels = []
for x, y in test_ds:
    labels.extend(y.numpy().tolist())
# print(labels)

# %% [markdown]
# ## Confusion Matrices

# %% [markdown]
# ### Confusion Matrix for FCNN model predictions

# %%
fcnn_predictions = fc_model.predict(test_ds)
fcnn_predictions = (fcnn_predictions > 0.5).astype(np.uint8)
fcnn_predictions = fcnn_predictions.reshape(160,).tolist()
# Out:
# 5/5 [==============================] - 0s 12ms/step

# %%
mpl.rcParams['font.family'] = 'serif'
mpl.rcParams['font.size'] = '24'

conf_matrix = confusion_matrix(labels, fcnn_predictions)
disp = ConfusionMatrixDisplay(confusion_matrix=conf_matrix, display_labels=['Book', 'Notebook'])
disp.plot(cmap='Blues', values_format='d')


plt.show()

# %%
conf_matrix
# Out:
# array([[63, 15],
#        [42, 40]])

# %% [markdown]
# ### Confusion matrix for FCNN model predictions

# %%
scnn_predictions = scnn_model.predict(test_ds)
scnn_predictions = (scnn_predictions > 0.5).astype(np.uint8)
scnn_predictions = scnn_predictions.reshape(160,).tolist()
# Out:
# 5/5 [==============================] - 0s 5ms/step

# %%
conf_matrix = confusion_matrix(labels, scnn_predictions)
disp = ConfusionMatrixDisplay(confusion_matrix=conf_matrix, display_labels=['Book', 'Notebook'])
disp.plot(cmap='Blues', values_format='d')


plt.show()

# %% [markdown]
# ### Confusion matrix for VGG16 model predictions

# %%
vgg16_predictions = vgg16_model.predict(test_ds)
vgg16_predictions = (vgg16_predictions > 0.5).astype(np.uint8)
vgg16_predictions = vgg16_predictions.reshape(160,).tolist()
# Out:
# 1/5 [=====>........................] - ETA: 0s
# 5/5 [==============================] - 0s 4ms/step

# %%
conf_matrix = confusion_matrix(labels, vgg16_predictions)
disp = ConfusionMatrixDisplay(confusion_matrix=conf_matrix, display_labels=['Book', 'Notebook'])
disp.plot(cmap='Blues', values_format='d')
plt.show()
