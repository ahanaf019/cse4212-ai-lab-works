# %% [markdown]
# # CSE4212: Artificail Intelligence Lab
# ### **Date:** 2 March, 2024
#
# ## Group 2:
#
# - Nazmus Shakib
#
#   **ID:** 1910876105
#
#   **Session:** 2018-19
#
# - Md. Ahanaf Arif Khan
#
#   **ID:** 1910676110
#
#   **Session:** 2018-19
#
# - Farjana Aktar,
#
#   **ID:** 1912276145
#
#   **Session:** 2018-19
#
# - Mohammad Ashif,
#
#   **ID:** 1711076147
#
#   **Session:** 2016-17

# %% [markdown]
# # Assignment5 (Group-wise Submission)
#
# Write a report on the effect of transfer learning on binary classification done by your own model using your private dataset.

# %% [markdown]
# # Mount Google Drive
#
# Our dataset is stored in Google Drive. So, we need to mount drive first in order to load the dataset.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# # Import Dependencies

# %%
import tensorflow as tf
from tensorflow import keras
from keras import Input, Model
from keras.layers import Dense, Flatten, Conv2D, MaxPooling2D
from keras.optimizers import Adam
from keras.losses import CategoricalCrossentropy, BinaryCrossentropy
from keras.metrics import CategoricalAccuracy, BinaryAccuracy, Precision, Recall, F1Score
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.applications import vgg16
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

# %% [markdown]
# # Hyper-Parameters

# %%
batch_size = 32
image_size = (256, 256)
learning_rate = 1e-4
epochs = 30
label_mode = 'int'
monitor_metric = 'val_loss'

# %% [markdown]
# # Loading the Dataset

# %% [markdown]
# The dataset is stored as a zip file in google drive. First, we need to extract it.

# %%
dataset_base_path = '.'
db_name = 'dataset_256'
# !unzip -o -q '{dataset_base_path}/{db_name}'

# %% [markdown]
# Create a dataset object for train, validation and test datasets respectively.

# %%
train_ds = keras.utils.image_dataset_from_directory(
    f'{db_name}/train',
    image_size=image_size,
    batch_size=batch_size,
    label_mode=label_mode,
    shuffle=True
)

val_ds = keras.utils.image_dataset_from_directory(
    f'{db_name}/valid',
    image_size=image_size,
    batch_size=batch_size,
    label_mode=label_mode,
    shuffle=False
)

test_ds = keras.utils.image_dataset_from_directory(
    f'{db_name}/test',
    image_size=image_size,
    batch_size=batch_size,
    label_mode=label_mode,
    shuffle=False
)

# Used for plotting
class_names = train_ds.class_names


test_ds = test_ds.map(lambda x, y: (x, tf.cast(y, tf.float32)))
train_ds = train_ds.prefetch(tf.data.AUTOTUNE)
# Out:
# Found 782 files belonging to 2 classes.
# Found 106 files belonging to 2 classes.
# Found 160 files belonging to 2 classes.

# %%
print(train_ds)
print(class_names)
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# ['book', 'notebook']

# %% [markdown]
# # Plot Samples from the Dataset

# %% [markdown]
# Our dataset contains images of books and notebooks. The images are of  resolution 256 x 256 pixels. Let us view a few samples from the dataset.

# %%
for imgs, labels in train_ds:
  break

plt.figure(figsize=(10, 10))
mpl.rcParams['font.family'] = 'serif'
mpl.rcParams['font.size'] = 14

plt.suptitle('Dataset samples', fontsize=18)
for i in range(16):
  plt.subplot(4,4,i+1)
  plt.imshow(imgs[i] / 255)
  plt.axis('off')
  # plt.title('{}({})'.format(class_names[labels[i]], labels[i]))
  plt.title(f'{labels[i]}'.format(class_names[labels[i]], labels[i]))

plt.savefig("./{}.png".format('dataset-samples'), bbox_inches='tight', format='png', dpi=256)
plt.show();

# %% [markdown]
# # VGG16 Model With Randomlly Initialized Weights

# %% [markdown]
# ### Creating the VGG16 Model and Viewing its Summary

# %%
vgg16_model = vgg16.VGG16(include_top=False, weights=None, input_shape=image_size+(3,))

inputs = vgg16_model.input
x = Flatten()(vgg16_model.output)
x = Dense(256, activation='relu')(x)
x = Dense(128, activation='relu')(x)
outputs = Dense(1, activation='sigmoid')(x)

vgg16_model = keras.Model(inputs, outputs, name='VGG16_Model')
vgg16_model.summary()
# Out:
# Model: "VGG16_Model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 256, 256, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 256, 256, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 128, 128, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 128, 128, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 128, 128, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 64, 64, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 64, 64, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 32, 32, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 32, 32, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 16, 16, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 8, 8, 512)         0
#
#  flatten (Flatten)           (None, 32768)             0
#
#  dense (Dense)               (None, 256)               8388864
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dense_2 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 23136577 (88.26 MB)
# Trainable params: 23136577 (88.26 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Compile and Fit the Model

# %%
vgg16_model.compile(
    optimizer=Adam(learning_rate=learning_rate),
    loss=BinaryCrossentropy(),
    metrics=[BinaryAccuracy(name='accuracy')]
)

history = vgg16_model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=epochs,
    callbacks=[
        ModelCheckpoint('vgg16_model-noTL.keras', monitor=monitor_metric, save_weights_only=False, save_best_only=True, verbose=1),
    ],
)
# Out:
# Epoch 1/30
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1709868399.056449  194778 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 25/25 [==============================] - ETA: 0s - loss: 0.7285 - accuracy: 0.5588
# Epoch 1: val_loss improved from inf to 0.68351, saving model to vgg16_model-noTL.keras
# 25/25 [==============================] - 51s 1s/step - loss: 0.7285 - accuracy: 0.5588 - val_loss: 0.6835 - val_accuracy: 0.5660
# Epoch 2/30
# 25/25 [==============================] - ETA: 0s - loss: 0.
# Epoch 23/30
# 25/25 [==============================] - ETA: 0s - loss: 0.0391 - accuracy: 0.9808
# Epoch 23: val_loss did not improve from 0.64918
# 25/25 [==============================] - 7s 271ms/step - loss: 0.0391 - accuracy: 0.9808 - val_loss: 2.2435 - val_accuracy: 0.7358
# Epoch 24/30
# 25/25 [==============================] - ETA: 0s - loss: 0.0223 - accuracy: 0.9910
# Epoch 24: val_loss did not improve from 0.64918
# 25/25 [==============================] - 7s 270ms/step - loss: 0.0223 - accuracy: 0.9910 - val_loss: 2.6200 - val_accuracy: 0.6792
# Epoch 25/30
# 25/25 [==============================] - ETA: 0s - loss: 0.0891 - accuracy: 0.9629
# Epoch 25: val_loss did not improve from 0.64918
# 25/25 [==============================] - 7s 268ms/step - loss: 0.0891 - accuracy: 0.9629 - val_loss: 1.1394 - val_accuracy: 0.7264
# Epoch 26/30
# 25/25 [==============================] - ETA: 0s - loss: 0.0431 - accuracy: 0.9885
# Epoch 26: val_loss did not improve from 0.64918
# 25/25 [==============================] - 7s 272ms/step - loss: 0.0431 - accuracy: 0.9885 - val_loss: 2.0670 - val_accuracy: 0.6509
# Epoch 27/30
# 25/25 [==============================] - ETA: 0s - loss: 0.0298 - accuracy: 0.9910
# Epoch 27: val_loss did not improve from 0.64918
# 25/25 [==============================] - 7s 265ms/step - loss: 0.0298 - accuracy: 0.9910 - val_loss: 1.7561 - val_accuracy: 0.7264
# Epoch 28/30
# 25/25 [==============================] - ETA: 0s - loss: 0.0036 - accuracy: 1.0000
# Epoch 28: val_loss did not improve from 0.64918
# 25/25 [==============================] - 7s 262ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 2.4077 - val_accuracy: 0.7453
# Epoch 29/30
# 25/25 [==============================] - ETA: 0s - loss: 8.0906e-04 - accuracy: 1.0000
# Epoch 29: val_loss did not improve from 0.64918
# 25/25 [==============================] - 7s 263ms/step - loss: 8.0906e-04 - accuracy: 1.0000 - val_loss: 2.7527 - val_accuracy: 0.7264
# Epoch 30/30
# 25/25 [==============================] - ETA: 0s - loss: 1.3460e-04 - accuracy: 1.0000
# Epoch 30: val_loss did not improve from 0.64918
# 25/25 [==============================] - 7s 265ms/step - loss: 1.3460e-04 - accuracy: 1.0000 - val_loss: 2.8814 - val_accuracy: 0.7264

# %% [markdown]
# ### Plotting the loss and accuracy graphs

# %%
plt.figure(figsize=(16, 6))
plt.subplot(1,2,1)
plt.plot(history.history['loss'], '.-')
plt.plot(history.history['val_loss'], '.-')
plt.xlabel('Epoch')
plt.ylabel('Loss Value')
plt.legend(['loss', 'val_loss'])

plt.subplot(1,2,2)
plt.plot(history.history['accuracy'], '.-')
plt.plot(history.history['val_accuracy'], '.-')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1.1])
plt.legend(['accuracy', 'val_accuracy'])

plt.show()

# %% [markdown]
# ### Loading the best checkpoint and evaluating the model using the test dataset

# %%
vgg16_model = keras.models.load_model('vgg16_model-noTL.keras')

vgg16_model.compile(
    optimizer=Adam(learning_rate=learning_rate),
    loss=BinaryCrossentropy(),
    metrics=[
        BinaryAccuracy(name='accuracy'),
        Precision(name='precision'),
        Recall(name='recall'),
        F1Score(name='f1score'),
    ]
)

eval = vgg16_model.evaluate(test_ds, return_dict=True)

eval
# Out:
# 5/5 [==============================] - 1s 120ms/step - loss: 0.6171 - accuracy: 0.6375 - precision: 0.7143 - recall: 0.4878 - f1score: 0.6777
# {'loss': 0.6170639991760254,
#  'accuracy': 0.637499988079071,
#  'precision': 0.7142857313156128,
#  'recall': 0.4878048896789551,
#  'f1score': array([0.6776859], dtype=float32)}

# %% [markdown]
# # VGG16 Model with Imagenet Weights

# %% [markdown]
# ### Creating the VGG16 Model and viewing its Summary
# We apply transfer learning using the VGG16 model by first loading it using weights of the ImageNet dataset.

# %%
vgg16_model = vgg16.VGG16(include_top=False, weights='imagenet', input_shape=image_size+(3,))

inputs = vgg16_model.input
x = Flatten()(vgg16_model.output)
x = Dense(256, activation='relu')(x)
x = Dense(128, activation='relu')(x)
outputs = Dense(1, activation='sigmoid')(x)

vgg16_model = keras.Model(inputs, outputs, name='VGG16_Model_TL')
vgg16_model.summary(show_trainable=True)
# Out:
# Model: "VGG16_Model_TL"
# ____________________________________________________________________________
#  Layer (type)                Output Shape              Param #   Trainable
# ============================================================================
#  input_2 (InputLayer)        [(None, 256, 256, 3)]     0         Y
#
#  block1_conv1 (Conv2D)       (None, 256, 256, 64)      1792      Y
#
#  block1_conv2 (Conv2D)       (None, 256, 256, 64)      36928     Y
#
#  block1_pool (MaxPooling2D)  (None, 128, 128, 64)      0         Y
#
#  block2_conv1 (Conv2D)       (None, 128, 128, 128)     73856     Y
#
#  block2_conv2 (Conv2D)       (None, 128, 128, 128)     147584    Y
#
#  block2_pool (MaxPooling2D)  (None, 64, 64, 128)       0         Y
#
#  block3_conv1 (Conv2D)       (None, 64, 64, 256)       295168    Y
#
#  block3_conv2 (Conv2D)       (None, 64, 64, 256)       590080    Y
#
#  block3_conv3 (Conv2D)       (None, 64, 64, 256)       590080    Y
#
#  block3_pool (MaxPooling2D)  (None, 32, 32, 256)       0         Y
#
#  block4_conv1 (Conv2D)       (None, 32, 32, 512)       1180160   Y
#
#  block4_conv2 (Conv2D)       (None, 32, 32, 512)       2359808   Y
#
#  block4_conv3 (Conv2D)       (None, 32, 32, 512)       2359808   Y
#
#  block4_pool (MaxPooling2D)  (None, 16, 16, 512)       0         Y
#
#  block5_conv1 (Conv2D)       (None, 16, 16, 512)       2359808   Y
#
#  block5_conv2 (Conv2D)       (None, 16, 16, 512)       2359808   Y
#
#  block5_conv3 (Conv2D)       (None, 16, 16, 512)       2359808   Y
#
#  block5_pool (MaxPooling2D)  (None, 8, 8, 512)         0         Y
#
#  flatten_1 (Flatten)         (None, 32768)             0         Y
#
#  dense_3 (Dense)             (None, 256)               8388864   Y
#
#  dense_4 (Dense)             (None, 128)               32896     Y
#
#  dense_5 (Dense)             (None, 1)                 129       Y
#
# ============================================================================
# Total params: 23136577 (88.26 MB)
# Trainable params: 23136577 (88.26 MB)
# Non-trainable params: 0 (0.00 Byte)
# ____________________________________________________________________________

# %% [markdown]
# ### Freeze Layers
# First, we freeze the base model and only train the newly added layers. After that, we evaluate the model at this stage.

# %%
for layer in vgg16_model.layers[:-4]:
  layer.trainable = False
vgg16_model.summary(show_trainable=True)
# Out:
# Model: "VGG16_Model_TL"
# ____________________________________________________________________________
#  Layer (type)                Output Shape              Param #   Trainable
# ============================================================================
#  input_2 (InputLayer)        [(None, 256, 256, 3)]     0         N
#
#  block1_conv1 (Conv2D)       (None, 256, 256, 64)      1792      N
#
#  block1_conv2 (Conv2D)       (None, 256, 256, 64)      36928     N
#
#  block1_pool (MaxPooling2D)  (None, 128, 128, 64)      0         N
#
#  block2_conv1 (Conv2D)       (None, 128, 128, 128)     73856     N
#
#  block2_conv2 (Conv2D)       (None, 128, 128, 128)     147584    N
#
#  block2_pool (MaxPooling2D)  (None, 64, 64, 128)       0         N
#
#  block3_conv1 (Conv2D)       (None, 64, 64, 256)       295168    N
#
#  block3_conv2 (Conv2D)       (None, 64, 64, 256)       590080    N
#
#  block3_conv3 (Conv2D)       (None, 64, 64, 256)       590080    N
#
#  block3_pool (MaxPooling2D)  (None, 32, 32, 256)       0         N
#
#  block4_conv1 (Conv2D)       (None, 32, 32, 512)       1180160   N
#
#  block4_conv2 (Conv2D)       (None, 32, 32, 512)       2359808   N
#
#  block4_conv3 (Conv2D)       (None, 32, 32, 512)       2359808   N
#
#  block4_pool (MaxPooling2D)  (None, 16, 16, 512)       0         N
#
#  block5_conv1 (Conv2D)       (None, 16, 16, 512)       2359808   N
#
#  block5_conv2 (Conv2D)       (None, 16, 16, 512)       2359808   N
#
#  block5_conv3 (Conv2D)       (None, 16, 16, 512)       2359808   N
#
#  block5_pool (MaxPooling2D)  (None, 8, 8, 512)         0         N
#
#  flatten_1 (Flatten)         (None, 32768)             0         Y
#
#  dense_3 (Dense)             (None, 256)               8388864   Y
#
#  dense_4 (Dense)             (None, 128)               32896     Y
#
#  dense_5 (Dense)             (None, 1)                 129       Y
#
# ============================================================================
# Total params: 23136577 (88.26 MB)
# Trainable params: 8421889 (32.13 MB)
# Non-trainable params: 14714688 (56.13 MB)
# ____________________________________________________________________________

# %% [markdown]
# ### Apply Preprocessing Function
# Since we are using pretrained weights, we need to preprocess our inputs with an appropiate preprocessing function. One way of doing this is to map the preprocessing function to the dataset object.

# %%
prep_train_ds = train_ds.map(lambda x, y: (vgg16.preprocess_input(x), y))
prep_val_ds = val_ds.map(lambda x, y: (vgg16.preprocess_input(x), y))
prep_test_ds = test_ds.map(lambda x, y: (vgg16.preprocess_input(x), y))

# %% [markdown]
# ### Compile and Fit the model

# %%
vgg16_model.compile(
    optimizer=Adam(learning_rate=learning_rate),
    loss=BinaryCrossentropy(),
    metrics=[BinaryAccuracy(name='accuracy')]
)

history = vgg16_model.fit(
    prep_train_ds,
    validation_data=prep_val_ds,
    epochs=epochs,
    callbacks=[
        ModelCheckpoint('vgg16_model-halfTL.keras', monitor=monitor_metric, save_weights_only=False, save_best_only=True, verbose=1),
    ],
)
# Out:
# Epoch 1/30
# 25/25 [==============================] - ETA: 0s - loss: 0.9675 - accuracy: 0.8146
# Epoch 1: val_loss improved from inf to 0.69218, saving model to vgg16_model-halfTL.keras
# 25/25 [==============================] - 4s 139ms/step - loss: 0.9675 - accuracy: 0.8146 - val_loss: 0.6922 - val_accuracy: 0.8396
# Epoch 2/30
# 25/25 [==============================] - ETA: 0s - loss: 0.0159 - accuracy: 0.
- accuracy: 1.0000
# Epoch 25: val_loss did not improve from 0.55340
# 25/25 [==============================] - 3s 121ms/step - loss: 1.5693e-05 - accuracy: 1.0000 - val_loss: 0.6404 - val_accuracy: 0.8679
# Epoch 26/30
# 25/25 [==============================] - ETA: 0s - loss: 1.5008e-05 - accuracy: 1.0000
# Epoch 26: val_loss did not improve from 0.55340
# 25/25 [==============================] - 3s 120ms/step - loss: 1.5008e-05 - accuracy: 1.0000 - val_loss: 0.6416 - val_accuracy: 0.8679
# Epoch 27/30
# 25/25 [==============================] - ETA: 0s - loss: 1.4372e-05 - accuracy: 1.0000
# Epoch 27: val_loss did not improve from 0.55340
# 25/25 [==============================] - 3s 121ms/step - loss: 1.4372e-05 - accuracy: 1.0000 - val_loss: 0.6424 - val_accuracy: 0.8679
# Epoch 28/30
# 25/25 [==============================] - ETA: 0s - loss: 1.3765e-05 - accuracy: 1.0000
# Epoch 28: val_loss did not improve from 0.55340
# 25/25 [==============================] - 3s 119ms/step - loss: 1.3765e-05 - accuracy: 1.0000 - val_loss: 0.6435 - val_accuracy: 0.8679
# Epoch 29/30
# 25/25 [==============================] - ETA: 0s - loss: 1.3202e-05 - accuracy: 1.0000
# Epoch 29: val_loss did not improve from 0.55340
# 25/25 [==============================] - 3s 120ms/step - loss: 1.3202e-05 - accuracy: 1.0000 - val_loss: 0.6446 - val_accuracy: 0.8679
# Epoch 30/30
# 25/25 [==============================] - ETA: 0s - loss: 1.2660e-05 - accuracy: 1.0000
# Epoch 30: val_loss did not improve from 0.55340
# 25/25 [==============================] - 3s 120ms/step - loss: 1.2660e-05 - accuracy: 1.0000 - val_loss: 0.6452 - val_accuracy: 0.8679

# %% [markdown]
# ### Plot loss and accuracy graphs

# %%
plt.figure(figsize=(16, 6))
plt.subplot(1,2,1)
plt.plot(history.history['loss'], '.-')
plt.plot(history.history['val_loss'], '.-')
plt.xlabel('Epoch', fontsize=20)
plt.xticks(fontsize=16)
plt.ylabel('Loss Value',fontsize=20)
plt.yticks(fontsize=16)
plt.legend(['loss', 'val_loss'],fontsize=16)

plt.subplot(1,2,2)
plt.plot(history.history['accuracy'], '.-')
plt.plot(history.history['val_accuracy'], '.-')
plt.xlabel('Epoch',fontsize=20)
plt.xticks(fontsize=16)
plt.ylabel('Accuracy',fontsize=20)
plt.yticks(fontsize=16)
plt.ylim([0, 1.1])
plt.legend(['accuracy', 'val_accuracy'],fontsize=16)

plt.show()

# %% [markdown]
# ### Load the best checkpoint and evaluate the model using the test dataset

# %%
vgg16_model = keras.models.load_model('vgg16_model-halfTL.keras')

vgg16_model.compile(
    optimizer=Adam(learning_rate=learning_rate),
    loss=BinaryCrossentropy(),
    metrics=[
        BinaryAccuracy(name='accuracy'),
        Precision(name='precision'),
        Recall(name='recall'),
        F1Score(name='f1score'),
    ]
)

eval = vgg16_model.evaluate(prep_test_ds, return_dict=True)

eval
# Out:
# 5/5 [==============================] - 1s 111ms/step - loss: 1.3926 - accuracy: 0.8062 - precision: 0.9180 - recall: 0.6829 - f1score: 0.7080
# {'loss': 1.3925703763961792,
#  'accuracy': 0.8062499761581421,
#  'precision': 0.9180327653884888,
#  'recall': 0.6829268336296082,
#  'f1score': array([0.70796466], dtype=float32)}

# %% [markdown]
# ## Unfreeze all the layers
# Now, we unfreeze all the layers and compile and train the model again using the training dataset.

# %%
for layer in vgg16_model.layers:
  layer.trainable = True
vgg16_model.summary(show_trainable=True)
# Out:
# Model: "VGG16_Model_TL"
# ____________________________________________________________________________
#  Layer (type)                Output Shape              Param #   Trainable
# ============================================================================
#  input_2 (InputLayer)        [(None, 256, 256, 3)]     0         Y
#
#  block1_conv1 (Conv2D)       (None, 256, 256, 64)      1792      Y
#
#  block1_conv2 (Conv2D)       (None, 256, 256, 64)      36928     Y
#
#  block1_pool (MaxPooling2D)  (None, 128, 128, 64)      0         Y
#
#  block2_conv1 (Conv2D)       (None, 128, 128, 128)     73856     Y
#
#  block2_conv2 (Conv2D)       (None, 128, 128, 128)     147584    Y
#
#  block2_pool (MaxPooling2D)  (None, 64, 64, 128)       0         Y
#
#  block3_conv1 (Conv2D)       (None, 64, 64, 256)       295168    Y
#
#  block3_conv2 (Conv2D)       (None, 64, 64, 256)       590080    Y
#
#  block3_conv3 (Conv2D)       (None, 64, 64, 256)       590080    Y
#
#  block3_pool (MaxPooling2D)  (None, 32, 32, 256)       0         Y
#
#  block4_conv1 (Conv2D)       (None, 32, 32, 512)       1180160   Y
#
#  block4_conv2 (Conv2D)       (None, 32, 32, 512)       2359808   Y
#
#  block4_conv3 (Conv2D)       (None, 32, 32, 512)       2359808   Y
#
#  block4_pool (MaxPooling2D)  (None, 16, 16, 512)       0         Y
#
#  block5_conv1 (Conv2D)       (None, 16, 16, 512)       2359808   Y
#
#  block5_conv2 (Conv2D)       (None, 16, 16, 512)       2359808   Y
#
#  block5_conv3 (Conv2D)       (None, 16, 16, 512)       2359808   Y
#
#  block5_pool (MaxPooling2D)  (None, 8, 8, 512)         0         Y
#
#  flatten_1 (Flatten)         (None, 32768)             0         Y
#
#  dense_3 (Dense)             (None, 256)               8388864   Y
#
#  dense_4 (Dense)             (None, 128)               32896     Y
#
#  dense_5 (Dense)             (None, 1)                 129       Y
#
# ============================================================================
# Total params: 23136577 (88.26 MB)
# Trainable params: 23136577 (88.26 MB)
# Non-trainable params: 0 (0.00 Byte)
# ____________________________________________________________________________

# %% [markdown]
# ### Compile and Fit the Model

# %%
vgg16_model.compile(
    optimizer=Adam(learning_rate=learning_rate),
    loss=BinaryCrossentropy(),
    metrics=[BinaryAccuracy(name='accuracy')]
)

history = vgg16_model.fit(
    prep_train_ds,
    validation_data=prep_val_ds,
    epochs=epochs,
    callbacks=[
        ModelCheckpoint('vgg16_model-fullTL.keras', monitor=monitor_metric, save_weights_only=False, save_best_only=True, verbose=1),
    ],
)
# Out:
# Epoch 1/30
# 25/25 [==============================] - ETA: 0s - loss: 0.7768 - accuracy: 0.7928
# Epoch 1: val_loss improved from inf to 0.57690, saving model to vgg16_model-fullTL.keras
# 25/25 [==============================] - 10s 295ms/step - loss: 0.7768 - accuracy: 0.7928 - val_loss: 0.5769 - val_accuracy: 0.7736
# Epoch 2/30
# 25/25 [==============================] - ETA: 0s - loss: 0.1617 - accuracy: 0.9437
# Epoch 2: val_loss did not improve from 0.57690
# 25/25 [==============================] - 7s 266ms/step - loss: 0.1617 - accuracy: 0.9437 - val_loss: 0.8302 - val_accuracy: 0.8491
# Epoch 3/30
# 25/25 [==============================] - ETA: 0s - loss: 0.1484 - accuracy: 0.9514
# Epoch 3: val_loss did not improve from 0.57690
# 25/25 [==============================] - 7s 263ms/step - loss: 0.1484 - accuracy: 0.9514 - val_loss: 1.0173 - val_accuracy: 0.6792
# Epoch 4/30
# 25/25 [==============================] - ETA: 0s - loss: 0.1059 - accuracy: 0.9655
# Epoch 4: val_loss improved from 0.57690 to 0.43874, saving model to vgg16_model-fullTL.keras
# 25/25 [==============================] - 22s 889ms/step - loss: 0.1059 - accuracy: 0.9655 - val_loss: 0.4387 - val_accuracy: 0.8302
# Epoch 5/30
# 25/25 [==============================] - ETA: 0s - loss: 0.0213 - accuracy: 0.9936
# Epoch 5: val_loss did not improve from 0.43874
# 25/25 [==============================] - 7s 262ms/step - loss: 0.0213 - accuracy: 0.9936 - val_loss: 0.7750 - val_accuracy: 0.8962
# Epoch 6/30
# 25/25 [==============================] - ETA: 0s - loss: 0.0167 - accuracy: 0.9936
# Epoch 6: val_loss improved from 0.43874 to 0.40742, saving model to vgg16_model-fullTL.keras
# 25/25 [==============================] - 18s 744ms/step - loss: 0.0167 - accuracy: 0.9936 - val_loss: 0.4074 - val_accuracy: 0.8962
# Epoch 7/30
# 25/25 [==============================] - ETA: 0s - loss: 0.0195 - accuracy: 0.9898
# Epoch 7: val_loss did not improve from 0.40742
# 25/25 [==============================] - 7s 262ms/step - loss: 0.0195 - accuracy: 0.9898 - val_loss: 0.4534 - val_accuracy: 0.9245
# Epoch 8/30
# 25/25 [==============================] - ETA: 0s - loss: 0.0809 - accuracy: 0.9770
# Epoch 8: val_loss did not improve from 0.40742
# 25/25 [==============================] - 7s 263ms/step - loss: 0.0809 - accuracy: 0.9770 - val_loss: 0.5543 - val_accuracy: 0.8491
# Epoch 9/30
# 25/25 [==============================] - ETA: 0s - loss: 0.0375 - accuracy: 0.9872
# Epoch 9: val_loss did not improve from 0.40742
# 25/25 [==============================] - 7s 262ms/step - loss: 0.0375 - accuracy: 0.9872 - val_loss: 0.6311 - val_accuracy: 0.8679
# Epoch 10/30
# 25/25 [==============================] - ETA: 0s - loss: 0.0221 - accuracy: 0.9898
# Epoch 10: val_loss did not improve from 0.40742
# 25/25 [==============================] - 7s 262ms/step - loss: 0.0221 - accuracy: 0.9898 - val_loss: 0.5633 - val_accuracy: 0.8868
# Epoch 11/30
# 25/25 [==============================] - ETA: 0s - loss: 0.0138 - accuracy: 0.9936
# Epoch 11: val_loss did not improve from 0.40742
# 25/25 [==============================] - 7s 262ms/step - loss: 0.0138 - accuracy: 0.9936 - val_loss: 1.1972 - val_accuracy: 0.8774
# Epoch 12/30
# 25/25 [==============================] - ETA: 0s - loss: 0.0235 - accuracy: 0.9910
# Epoch 12: val_loss did not improve from 0.40742
# 25/25 [==============================] - 7s 262ms/step - loss: 0.0235 - accuracy: 0.9910 - val_loss: 0.8541 - val_accuracy: 0.8868
# Epoch 13/30
# 25/25 [==============================] - ETA: 0s - loss: 0.0191 - accuracy: 0.9949
# Epoch 13: val_loss did not improve from 0.40742
# 25/25 [==============================] - 7s 263ms/step - loss: 0.0191 - accuracy: 0.9949 - val_loss: 2.0124 - val_accuracy: 0.7736
# Epoch 14/30
# 25/25 [==============================] - ETA: 0s - loss: 0.0191 - accuracy: 0.9936
# Epoch 14: val_loss did not improve from 0.40742
# 25/25 [==============================] - 7s 262ms/step - loss: 0.0191 - accuracy: 0.9936 - val_loss: 3.2421 - val_accuracy: 0.7547
# Epoch 15/30
# 25/25 [==============================] - ETA: 0s - loss: 0.0941 - accuracy: 0.9731
# Epoch 15: val_loss did not improve from 0.40742
# 25/25 [==============================] - 7s 262ms/step - loss: 0.0941 - accuracy: 0.9731 - val_loss: 0.9795 - val_accuracy: 0.7547
# Epoch 16/30
# 25/25 [==============================] - ETA: 0s - loss: 0.1003 - accuracy: 0.9693
# Epoch 16: val_loss did not improve from 0.40742
# 25/25 [==============================] - 7s 263ms/step - loss: 0.1003 - accuracy: 0.9693 - val_loss: 0.5405 - val_accuracy: 0.8491
# Epoch 17/30
# 25/25 [==============================] - ETA: 0s - loss: 0.0887 - accuracy: 0.9834
# Epoch 17: val_loss did not improve from 0.40742
# 25/25 [==============================] - 7s 262ms/step - loss: 0.0887 - accuracy: 0.9834 - val_loss: 0.7034 - val_accuracy: 0.8302
# Epoch 18/30
# 25/25 [==============================] - ETA: 0s - loss: 0.0544 - accuracy: 0.9795
# Epoch 18: val_loss did not improve from 0.40742
# 25/25 [==============================] - 7s 263ms/step - loss: 0.0544 - accuracy: 0.9795 - val_loss: 0.8364 - val_accuracy: 0.8774
# Epoch 19/30
# 25/25 [==============================] - ETA: 0s - loss: 0.0070 - accuracy: 0.9974
# Epoch 19: val_loss did not improve from 0.40742
# 25/25 [==============================] - 7s 263ms/step - loss: 0.0070 - accuracy: 0.9974 - val_loss: 1.0311 - val_accuracy: 0.8585
# Epoch 20/30
# 25/25 [==============================] - ETA: 0s - loss: 0.0201 - accuracy: 0.9923
# Epoch 20: val_loss did not improve from 0.40742
# 25/25 [==============================] - 7s 263ms/step - loss: 0.0201 - accuracy: 0.9923 - val_loss: 0.7878 - val_accuracy: 0.8491
# Epoch 21/30
# 25/25 [==============================] - ETA: 0s - loss: 0.0105 - accuracy: 0.9962
# Epoch 21: val_loss did not improve from 0.40742
# 25/25 [==============================] - 7s 263ms/step - loss: 0.0105 - accuracy: 0.9962 - val_loss: 0.5002 - val_accuracy: 0.8679
# Epoch 22/30
# 25/25 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 1.0000
# Epoch 22: val_loss did not improve from 0.40742
# 25/25 [==============================] - 7s 264ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.4794 - val_accuracy: 0.8962
# Epoch 23/30
# 25/25 [==============================] - ETA: 0s - loss: 0.0052 - accuracy: 0.9987
# Epoch 23: val_loss improved from 0.40742 to 0.39789, saving model to vgg16_model-fullTL.keras
# 25/25 [==============================] - 14s 586ms/step - loss: 0.0052 - accuracy: 0.9987 - val_loss: 0.3979 - val_accuracy: 0.8962
# Epoch 24/30
# 25/25 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 1.0000
# Epoch 24: val_loss did not improve from 0.39789
# 25/25 [==============================] - 7s 262ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.8044 - val_accuracy: 0.8868
# Epoch 25/30
# 25/25 [==============================] - ETA: 0s - loss: 1.1627e-04 - accuracy: 1.0000
# Epoch 25: val_loss did not improve from 0.39789
# 25/25 [==============================] - 7s 263ms/step - loss: 1.1627e-04 - accuracy: 1.0000 - val_loss: 0.8976 - val_accuracy: 0.8868
# Epoch 26/30
# 25/25 [==============================] - ETA: 0s - loss: 4.2103e-05 - accuracy: 1.0000
# Epoch 26: val_loss did not improve from 0.39789
# 25/25 [==============================] - 7s 263ms/step - loss: 4.2103e-05 - accuracy: 1.0000 - val_loss: 0.8622 - val_accuracy: 0.8868
# Epoch 27/30
# 25/25 [==============================] - ETA: 0s - loss: 2.4406e-05 - accuracy: 1.0000
# Epoch 27: val_loss did not improve from 0.39789
# 25/25 [==============================] - 7s 263ms/step - loss: 2.4406e-05 - accuracy: 1.0000 - val_loss: 0.8558 - val_accuracy: 0.8868
# Epoch 28/30
# 25/25 [==============================] - ETA: 0s - loss: 2.0621e-05 - accuracy: 1.0000
# Epoch 28: val_loss did not improve from 0.39789
# 25/25 [==============================] - 7s 262ms/step - loss: 2.0621e-05 - accuracy: 1.0000 - val_loss: 0.8541 - val_accuracy: 0.8868
# Epoch 29/30
# 25/25 [==============================] - ETA: 0s - loss: 1.8172e-05 - accuracy: 1.0000
# Epoch 29: val_loss did not improve from 0.39789
# 25/25 [==============================] - 7s 263ms/step - loss: 1.8172e-05 - accuracy: 1.0000 - val_loss: 0.8540 - val_accuracy: 0.8868
# Epoch 30/30
# 25/25 [==============================] - ETA: 0s - loss: 1.6146e-05 - accuracy: 1.0000
# Epoch 30: val_loss did not improve from 0.39789
# 25/25 [==============================] - 7s 263ms/step - loss: 1.6146e-05 - accuracy: 1.0000 - val_loss: 0.8550 - val_accuracy: 0.8868

# %% [markdown]
# ### Plotting loss and accuracy graphs

# %%
plt.figure(figsize=(16, 6))
plt.subplot(1,2,1)
plt.plot(history.history['loss'], '.-')
plt.plot(history.history['val_loss'], '.-')
plt.xlabel('Epoch', fontsize=20)
plt.xticks(fontsize=16)
plt.ylabel('Loss Value',fontsize=20)
plt.yticks(fontsize=16)
plt.legend(['loss', 'val_loss'],fontsize=16)

plt.subplot(1,2,2)
plt.plot(history.history['accuracy'], '.-')
plt.plot(history.history['val_accuracy'], '.-')
plt.xlabel('Epoch',fontsize=20)
plt.xticks(fontsize=16)
plt.ylabel('Accuracy',fontsize=20)
plt.yticks(fontsize=16)
plt.ylim([0, 1.1])
plt.legend(['accuracy', 'val_accuracy'],fontsize=16)

# plt.savefig("./{}.eps".format('vgg-c-2'), bbox_inches='tight', format='eps', dpi=1000)
plt.show()

# %% [markdown]
# ### Load the best checkpoint and evaluate the model using the test dataset

# %%
vgg16_model = keras.models.load_model('vgg16_model-fullTL.keras')

vgg16_model.compile(
    optimizer=Adam(learning_rate=learning_rate),
    loss=BinaryCrossentropy(),
    metrics=[
        BinaryAccuracy(name='accuracy'),
        Precision(name='precision'),
        Recall(name='recall'),
        F1Score(name='f1score'),
    ]
)

eval = vgg16_model.evaluate(prep_test_ds, return_dict=True)

eval
# Out:
# 5/5 [==============================] - 1s 105ms/step - loss: 1.2082 - accuracy: 0.7375 - precision: 0.7778 - recall: 0.6829 - f1score: 0.7225
# {'loss': 1.208211898803711,
#  'accuracy': 0.737500011920929,
#  'precision': 0.7777777910232544,
#  'recall': 0.6829268336296082,
#  'f1score': array([0.722467], dtype=float32)}
