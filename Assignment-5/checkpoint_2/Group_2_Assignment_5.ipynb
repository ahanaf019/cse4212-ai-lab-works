# %% [markdown]
# # CSE4212: Artificail Intelligence Lab
# ### **Date:** 2 March, 2024
#
# ## Group 2:
#
# - Nazmus Shakib
#
#   **ID:** 1910876105
#
#   **Session:** 2018-19
#
# - Md. Ahanaf Arif Khan
#
#   **ID:** 1910676110
#
#   **Session:** 2018-19
#
# - Farjana Aktar,
#
#   **ID:** 1912276145
#
#   **Session:** 2018-19
#
# - Mohammad Ashif,
#
#   **ID:** 1711076147
#
#   **Session:** 2016-17

# %% [markdown]
# # Assignment5 (Group-wise Submission)
#
# Write a report on the effect of transfer learning on binary classification done by your own model using your private dataset.

# %% [markdown]
# # Mount Google Drive
#
# Our dataset is stored in Google Drive. So, we need to mount drive first in order to load the dataset.

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true' 

# https://github.com/tensorflow/tensorflow/issues/53519
os.environ['TF_DEVICE_MIN_SYS_MEMORY_IN_MB'] = '64'

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# # Import Dependencies

# %%
import tensorflow as tf
from tensorflow import keras
from keras import Input, Model
from keras.layers import Dense, Flatten, Conv2D, MaxPooling2D
from keras.optimizers import Adam
from keras.losses import CategoricalCrossentropy, BinaryCrossentropy
from keras.metrics import CategoricalAccuracy, BinaryAccuracy, Precision, Recall, F1Score
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.applications import vgg16
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from keras.regularizers import L2

# %% [markdown]
# # Hyper-Parameters

# %%
batch_size = 32
image_size = (256, 256)
learning_rate = 1e-4
epochs = 30
label_mode = 'int'
monitor_metric = 'val_loss'

# %% [markdown]
# # Loading the Dataset

# %% [markdown]
# The dataset is stored as a zip file in google drive. First, we need to extract it.

# %%
dataset_base_path = '.'
db_name = 'dataset_256'
# !unzip -o -q '{dataset_base_path}/{db_name}'

# %% [markdown]
# Create a dataset object for train, validation and test datasets respectively.

# %%
train_ds = keras.utils.image_dataset_from_directory(
    f'{db_name}/train',
    image_size=image_size,
    batch_size=batch_size,
    label_mode=label_mode,
    shuffle=True
)

val_ds = keras.utils.image_dataset_from_directory(
    f'{db_name}/valid',
    image_size=image_size,
    batch_size=batch_size,
    label_mode=label_mode,
    shuffle=False
)

test_ds = keras.utils.image_dataset_from_directory(
    f'{db_name}/test',
    image_size=image_size,
    batch_size=batch_size,
    label_mode=label_mode,
    shuffle=False
)

# Used for plotting
class_names = train_ds.class_names


test_ds = test_ds.map(lambda x, y: (x, tf.cast(y, tf.float32)))
train_ds = train_ds.prefetch(tf.data.AUTOTUNE)
# Out:
# Found 782 files belonging to 2 classes.
# Found 106 files belonging to 2 classes.
# Found 160 files belonging to 2 classes.

# %%
print(train_ds)
print(class_names)
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# ['book', 'notebook']

# %% [markdown]
# # Plot Samples from the Dataset

# %% [markdown]
# Our dataset contains images of books and notebooks. The images are of  resolution 256 x 256 pixels. Let us view a few samples from the dataset.

# %%
for imgs, labels in train_ds:
  break

plt.figure(figsize=(10, 10))
mpl.rcParams['font.family'] = 'serif'
mpl.rcParams['font.size'] = 14

plt.suptitle('Dataset samples', fontsize=18)
for i in range(16):
  plt.subplot(4,4,i+1)
  plt.imshow(imgs[i] / 255)
  plt.axis('off')
  # plt.title('{}({})'.format(class_names[labels[i]], labels[i]))
  plt.title(f'{labels[i]}'.format(class_names[labels[i]], labels[i]))

plt.savefig("./{}.png".format('dataset-samples'), bbox_inches='tight', format='png', dpi=256)
plt.show();

# %% [markdown]
# # VGG16 Model With Randomlly Initialized Weights

# %% [markdown]
# ### Creating the VGG16 Model and Viewing its Summary

# %%
vgg16_model = vgg16.VGG16(include_top=False, weights=None, input_shape=image_size+(3,))

inputs = vgg16_model.input
x = Flatten()(vgg16_model.output)
x = Dense(256, activation='relu')(x)
x = Dense(128, activation='relu')(x)
outputs = Dense(1, activation='sigmoid')(x)

vgg16_model = keras.Model(inputs, outputs, name='VGG16_Model')
vgg16_model.summary()
# Out:
# Model: "VGG16_Model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 256, 256, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 256, 256, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 128, 128, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 128, 128, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 128, 128, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 64, 64, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 64, 64, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 32, 32, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 32, 32, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 16, 16, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 8, 8, 512)         0
#
#  flatten (Flatten)           (None, 32768)             0
#
#  dense (Dense)               (None, 256)               8388864
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dense_2 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 23136577 (88.26 MB)
# Trainable params: 23136577 (88.26 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Compile and Fit the Model

# %%
vgg16_model.compile(
    optimizer=Adam(learning_rate=learning_rate),
    loss=BinaryCrossentropy(),
    metrics=[BinaryAccuracy(name='accuracy')]
)

history = vgg16_model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=epochs,
    callbacks=[
        ModelCheckpoint('vgg16_model-noTL.keras', monitor=monitor_metric, save_weights_only=False, save_best_only=True, verbose=1),
    ],
)
# Out:
# Epoch 1/30
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1709867002.764818  140816 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 25/25 [==============================] - ETA: 0s - loss: 0.7362 - accuracy: 0.5192
# Epoch 1: val_loss improved from inf to 0.69427, saving model to vgg16_model-noTL.keras
# 25/25 [==============================] - 40s 718ms/step - loss: 0.7362 - accuracy: 0.5192 - val_loss: 0.6943 - val_accuracy: 0.4717
# Epoch 2/30
# 25/25 [==============================] - ETA: 0s - loss: 0.6719 - accuracy: 0.6151
# Epoch 2: val_loss improved from 0.69427 to 0.68856, saving model to vgg16_model-noTL.keras
# 25/25 [==============================] - 15s 614ms/step - loss: 0.6719 - accuracy: 0.6151 - val_loss: 0.6886 - val_accuracy: 0.5189
# Epoch 3/30
# 25/25 [==============================] - ETA: 0s - loss: 0.5837 - accuracy: 0.6931
# Epoch 3: val_loss did not improve from 0.68856
# 25/25 [==============================] - 7s 272ms/step - loss: 0.5837 - accuracy: 0.6931 - val_loss: 0.7734 - val_accuracy: 0.4623
# Epoch 4/30
# 25/25 [==============================] - ETA: 0s - loss: 0.5164 - accuracy: 0.7442
# Epoch 4: val_loss did not improve from 0.68856
# 25/25 [==============================] - 7s 273ms/step - loss: 0.5164 - accuracy: 0.7442 - val_loss: 0.7676 - val_accuracy: 0.5283
# Epoch 5/30
# 25/25 [==============================] - ETA: 0s - loss: 0.4564 - accuracy: 0.7724
# Epoch 5: val_loss did not improve from 0.68856
# 25/25 [==============================] - 7s 270ms/step - loss: 0.4564 - accuracy: 0.7724 - val_loss: 0.7408 - val_accuracy: 0.5755
# Epoch 6/30
# 25/25 [==============================] - ETA: 0s - loss: 0.4545 - accuracy: 0.7749
# Epoch 6: val_loss did not improve from 0.68856
# 25/25 [==============================] - 7s 268ms/step - loss: 0.4545 - accuracy: 0.7749 - val_loss: 0.8254 - val_accuracy: 0.4811
# Epoch 7/30
# 25/25 [==============================] - ETA: 0s - loss: 0.4617 - accuracy: 0.7634
# Epoch 7: val_loss improved from 0.68856 to 0.68473, saving model to vgg16_model-noTL.keras
# 25/25 [==============================] - 29s 1s/step - loss: 0.4617 - accuracy: 0.7634 - val_loss: 0.6847 - val_accuracy: 0.6226
# Epoch 8/30
# 25/25 [==============================] - ETA: 0s - loss: 0.4171 - accuracy: 0.8120
# Epoch 8: val_loss improved from 0.68473 to 0.65231, saving model to vgg16_model-noTL.keras
# 25/25 [==============================] - 14s 582ms/step - loss: 0.4171 - accuracy: 0.8120 - val_loss: 0.6523 - val_accuracy: 0.7453
# Epoch 9/30
# 25/25 [==============================] - ETA: 0s - loss: 0.3742 - accuracy: 0.8350
# Epoch 9: val_loss did not improve from 0.65231
# 25/25 [==============================] - 7s 272ms/step - loss: 0.3742 - accuracy: 0.8350 - val_loss: 0.9067 - val_accuracy: 0.6226
# Epoch 10/30
# 25/25 [==============================] - ETA: 0s - loss: 0.2885 - accuracy: 0.8683
# Epoch 10: val_loss did not improve from 0.65231
# 25/25 [==============================] - 7s 268ms/step - loss: 0.2885 - accuracy: 0.8683 - val_loss: 1.0261 - val_accuracy: 0.6887
# Epoch 11/30
# 25/25 [==============================] - ETA: 0s - loss: 0.3291 - accuracy: 0.8427
# Epoch 11: val_loss did not improve from 0.65231
# 25/25 [==============================] - 7s 274ms/step - loss: 0.3291 - accuracy: 0.8427 - val_loss: 1.0001 - val_accuracy: 0.6226
# Epoch 12/30
# 25/25 [==============================] - ETA: 0s - loss: 0.2545 - accuracy: 0.8926
# Epoch 12: val_loss did not improve from 0.65231
# 25/25 [==============================] - 7s 280ms/step - loss: 0.2545 - accuracy: 0.8926 - val_loss: 1.0423 - val_accuracy: 0.6321
# Epoch 13/30
# 25/25 [==============================] - ETA: 0s - loss: 0.3146 - accuracy: 0.8555
# Epoch 13: val_loss did not improve from 0.65231
# 25/25 [==============================] - 7s 270ms/step - loss: 0.3146 - accuracy: 0.8555 - val_loss: 0.9575 - val_accuracy: 0.6981
# Epoch 14/30
# 25/25 [==============================] - ETA: 0s - loss: 0.2022 - accuracy: 0.9194
# Epoch 14: val_loss did not improve from 0.65231
# 25/25 [==============================] - 7s 274ms/step - loss: 0.2022 - accuracy: 0.9194 - val_loss: 1.8338 - val_accuracy: 0.6321
# Epoch 15/30
# 25/25 [==============================] - ETA: 0s - loss: 0.2331 - accuracy: 0.8990
# Epoch 15: val_loss did not improve from 0.65231
# 25/25 [==============================] - 7s 273ms/step - loss: 0.2331 - accuracy: 0.8990 - val_loss: 0.7825 - val_accuracy: 0.7642
# Epoch 16/30
# 25/25 [==============================] - ETA: 0s - loss: 0.1383 - accuracy: 0.9386
# Epoch 16: val_loss did not improve from 0.65231
# 25/25 [==============================] - 7s 274ms/step - loss: 0.1383 - accuracy: 0.9386 - val_loss: 2.3281 - val_accuracy: 0.5943
# Epoch 17/30
# 25/25 [==============================] - ETA: 0s - loss: 0.2112 - accuracy: 0.9105
# Epoch 17: val_loss did not improve from 0.65231
# 25/25 [==============================] - 7s 269ms/step - loss: 0.2112 - accuracy: 0.9105 - val_loss: 1.4551 - val_accuracy: 0.7547
# Epoch 18/30
# 25/25 [==============================] - ETA: 0s - loss: 0.1510 - accuracy: 0.9373
# Epoch 18: val_loss did not improve from 0.65231
# 25/25 [==============================] - 7s 271ms/step - loss: 0.1510 - accuracy: 0.9373 - val_loss: 0.9762 - val_accuracy: 0.6981
# Epoch 19/30
# 25/25 [==============================] - ETA: 0s - loss: 0.1832 - accuracy: 0.9258
# Epoch 19: val_loss did not improve from 0.65231
# 25/25 [==============================] - 7s 268ms/step - loss: 0.1832 - accuracy: 0.9258 - val_loss: 0.9661 - val_accuracy: 0.7547
# Epoch 20/30
# 25/25 [==============================] - ETA: 0s - loss: 0.0786 - accuracy: 0.9693
# Epoch 20: val_loss did not improve from 0.65231
# 25/25 [==============================] - 7s 266ms/step - loss: 0.0786 - accuracy: 0.9693 - val_loss: 1.7905 - val_accuracy: 0.7170
# Epoch 21/30
# 25/25 [==============================] - ETA: 0s - loss: 0.1036 - accuracy: 0.9552
# Epoch 21: val_loss did not improve from 0.65231
# 25/25 [==============================] - 7s 267ms/step - loss: 0.1036 - accuracy: 0.9552 - val_loss: 1.1958 - val_accuracy: 0.6981
# Epoch 22/30
# 25/25 [==============================] - ETA: 0s - loss: 0.1099 - accuracy: 0.9642
# Epoch 22: val_loss did not improve from 0.65231
# 25/25 [==============================] - 7s 268ms/step - loss: 0.1099 - accuracy: 0.9642 - val_loss: 1.4526 - val_accuracy: 0.7170
# Epoch 23/30
# 25/25 [==============================] - ETA: 0s - loss: 0.0408 - accuracy: 0.9834
# Epoch 23: val_loss did not improve from 0.65231
# 25/25 [==============================] - 7s 267ms/step - loss: 0.0408 - accuracy: 0.9834 - val_loss: 1.7140 - val_accuracy: 0.7453
# Epoch 24/30
# 25/25 [==============================] - ETA: 0s - loss: 0.0445 - accuracy: 0.9859
# Epoch 24: val_loss did not improve from 0.65231
# 25/25 [==============================] - 7s 269ms/step - loss: 0.0445 - accuracy: 0.9859 - val_loss: 2.0106 - val_accuracy: 0.7075
# Epoch 25/30
# 25/25 [==============================] - ETA: 0s - loss: 0.0189 - accuracy: 0.9910
# Epoch 25: val_loss did not improve from 0.65231
# 25/25 [==============================] - 7s 275ms/step - loss: 0.0189 - accuracy: 0.9910 - val_loss: 1.6920 - val_accuracy: 0.7547
# Epoch 26/30
# 25/25 [==============================] - ETA: 0s - loss: 0.0297 - accuracy: 0.9885
# Epoch 26: val_loss did not improve from 0.65231
# 25/25 [==============================] - 7s 277ms/step - loss: 0.0297 - accuracy: 0.9885 - val_loss: 1.9356 - val_accuracy: 0.7264
# Epoch 27/30
# 25/25 [==============================] - ETA: 0s - loss: 0.0504 - accuracy: 0.9910
# Epoch 27: val_loss did not improve from 0.65231
# 25/25 [==============================] - 7s 275ms/step - loss: 0.0504 - accuracy: 0.9910 - val_loss: 3.4595 - val_accuracy: 0.7075
# Epoch 28/30
# 25/25 [==============================] - ETA: 0s - loss: 0.1032 - accuracy: 0.9629
# Epoch 28: val_loss did not improve from 0.65231
# 25/25 [==============================] - 7s 267ms/step - loss: 0.1032 - accuracy: 0.9629 - val_loss: 1.0277 - val_accuracy: 0.7453
# Epoch 29/30
# 25/25 [==============================] - ETA: 0s - loss: 0.0480 - accuracy: 0.9859
# Epoch 29: val_loss did not improve from 0.65231
# 25/25 [==============================] - 7s 266ms/step - loss: 0.0480 - accuracy: 0.9859 - val_loss: 1.6578 - val_accuracy: 0.7453
# Epoch 30/30
# 25/25 [==============================] - ETA: 0s - loss: 0.0298 - accuracy: 0.9885
# Epoch 30: val_loss did not improve from 0.65231
# 25/25 [==============================] - 7s 267ms/step - loss: 0.0298 - accuracy: 0.9885 - val_loss: 3.2959 - val_accuracy: 0.6792

# %% [markdown]
# ### Plotting the loss and accuracy graphs

# %%
plt.figure(figsize=(16, 6))
plt.subplot(1,2,1)
plt.plot(history.history['loss'], '.-')
plt.plot(history.history['val_loss'], '.-')
plt.xlabel('Epoch')
plt.ylabel('Loss Value')
plt.legend(['loss', 'val_loss'])

plt.subplot(1,2,2)
plt.plot(history.history['accuracy'], '.-')
plt.plot(history.history['val_accuracy'], '.-')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1.1])
plt.legend(['accuracy', 'val_accuracy'])

plt.show()

# %% [markdown]
# ### Loading the best checkpoint and evaluating the model using the test dataset

# %%
vgg16_model = keras.models.load_model('vgg16_model-noTL.keras')

vgg16_model.compile(
    optimizer=Adam(learning_rate=learning_rate),
    loss=BinaryCrossentropy(),
    metrics=[
        BinaryAccuracy(name='accuracy'),
        Precision(name='precision'),
        Recall(name='recall'),
        F1Score(name='f1score'),
    ]
)

eval = vgg16_model.evaluate(test_ds, return_dict=True)

eval
# Out:
# 5/5 [==============================] - 1s 122ms/step - loss: 0.9055 - accuracy: 0.6125 - precision: 0.6064 - recall: 0.6951 - f1score: 0.6777
# {'loss': 0.9054861068725586,
#  'accuracy': 0.612500011920929,
#  'precision': 0.6063829660415649,
#  'recall': 0.6951219439506531,
#  'f1score': array([0.6776859], dtype=float32)}

# %% [markdown]
# # VGG16 Model with Imagenet Weights

# %% [markdown]
# ### Creating the VGG16 Model and viewing its Summary
# We apply transfer learning using the VGG16 model by first loading it using weights of the ImageNet dataset.

# %%
vgg16_model = vgg16.VGG16(include_top=False, weights='imagenet', input_shape=image_size+(3,))

inputs = vgg16_model.input
x = Flatten()(vgg16_model.output)
x = Dense(256, activation='relu')(x)
x = Dense(128, activation='relu')(x)
outputs = Dense(1, activation='sigmoid')(x)

vgg16_model = keras.Model(inputs, outputs, name='VGG16_Model_TL')
vgg16_model.summary(show_trainable=True)
# Out:
# Model: "VGG16_Model_TL"
# ____________________________________________________________________________
#  Layer (type)                Output Shape              Param #   Trainable
# ============================================================================
#  input_2 (InputLayer)        [(None, 256, 256, 3)]     0         Y
#
#  block1_conv1 (Conv2D)       (None, 256, 256, 64)      1792      Y
#
#  block1_conv2 (Conv2D)       (None, 256, 256, 64)      36928     Y
#
#  block1_pool (MaxPooling2D)  (None, 128, 128, 64)      0         Y
#
#  block2_conv1 (Conv2D)       (None, 128, 128, 128)     73856     Y
#
#  block2_conv2 (Conv2D)       (None, 128, 128, 128)     147584    Y
#
#  block2_pool (MaxPooling2D)  (None, 64, 64, 128)       0         Y
#
#  block3_conv1 (Conv2D)       (None, 64, 64, 256)       295168    Y
#
#  block3_conv2 (Conv2D)       (None, 64, 64, 256)       590080    Y
#
#  block3_conv3 (Conv2D)       (None, 64, 64, 256)       590080    Y
#
#  block3_pool (MaxPooling2D)  (None, 32, 32, 256)       0         Y
#
#  block4_conv1 (Conv2D)       (None, 32, 32, 512)       1180160   Y
#
#  block4_conv2 (Conv2D)       (None, 32, 32, 512)       2359808   Y
#
#  block4_conv3 (Conv2D)       (None, 32, 32, 512)       2359808   Y
#
#  block4_pool (MaxPooling2D)  (None, 16, 16, 512)       0         Y
#
#  block5_conv1 (Conv2D)       (None, 16, 16, 512)       2359808   Y
#
#  block5_conv2 (Conv2D)       (None, 16, 16, 512)       2359808   Y
#
#  block5_conv3 (Conv2D)       (None, 16, 16, 512)       2359808   Y
#
#  block5_pool (MaxPooling2D)  (None, 8, 8, 512)         0         Y
#
#  flatten_1 (Flatten)         (None, 32768)             0         Y
#
#  dense_3 (Dense)             (None, 256)               8388864   Y
#
#  dense_4 (Dense)             (None, 128)               32896     Y
#
#  dense_5 (Dense)             (None, 1)                 129       Y
#
# ============================================================================
# Total params: 23136577 (88.26 MB)
# Trainable params: 23136577 (88.26 MB)
# Non-trainable params: 0 (0.00 Byte)
# ____________________________________________________________________________

# %% [markdown]
# ### Freeze Layers
# First, we freeze the base model and only train the newly added layers. After that, we evaluate the model at this stage.

# %%
for layer in vgg16_model.layers[:-4]:
  layer.trainable = False
vgg16_model.summary(show_trainable=True)
# Out:
# Model: "VGG16_Model_TL"
# ____________________________________________________________________________
#  Layer (type)                Output Shape              Param #   Trainable
# ============================================================================
#  input_2 (InputLayer)        [(None, 256, 256, 3)]     0         N
#
#  block1_conv1 (Conv2D)       (None, 256, 256, 64)      1792      N
#
#  block1_conv2 (Conv2D)       (None, 256, 256, 64)      36928     N
#
#  block1_pool (MaxPooling2D)  (None, 128, 128, 64)      0         N
#
#  block2_conv1 (Conv2D)       (None, 128, 128, 128)     73856     N
#
#  block2_conv2 (Conv2D)       (None, 128, 128, 128)     147584    N
#
#  block2_pool (MaxPooling2D)  (None, 64, 64, 128)       0         N
#
#  block3_conv1 (Conv2D)       (None, 64, 64, 256)       295168    N
#
#  block3_conv2 (Conv2D)       (None, 64, 64, 256)       590080    N
#
#  block3_conv3 (Conv2D)       (None, 64, 64, 256)       590080    N
#
#  block3_pool (MaxPooling2D)  (None, 32, 32, 256)       0         N
#
#  block4_conv1 (Conv2D)       (None, 32, 32, 512)       1180160   N
#
#  block4_conv2 (Conv2D)       (None, 32, 32, 512)       2359808   N
#
#  block4_conv3 (Conv2D)       (None, 32, 32, 512)       2359808   N
#
#  block4_pool (MaxPooling2D)  (None, 16, 16, 512)       0         N
#
#  block5_conv1 (Conv2D)       (None, 16, 16, 512)       2359808   N
#
#  block5_conv2 (Conv2D)       (None, 16, 16, 512)       2359808   N
#
#  block5_conv3 (Conv2D)       (None, 16, 16, 512)       2359808   N
#
#  block5_pool (MaxPooling2D)  (None, 8, 8, 512)         0         N
#
#  flatten_1 (Flatten)         (None, 32768)             0         Y
#
#  dense_3 (Dense)             (None, 256)               8388864   Y
#
#  dense_4 (Dense)             (None, 128)               32896     Y
#
#  dense_5 (Dense)             (None, 1)                 129       Y
#
# ============================================================================
# Total params: 23136577 (88.26 MB)
# Trainable params: 8421889 (32.13 MB)
# Non-trainable params: 14714688 (56.13 MB)
# ____________________________________________________________________________

# %% [markdown]
# ### Apply Preprocessing Function
# Since we are using pretrained weights, we need to preprocess our inputs with an appropiate preprocessing function. One way of doing this is to map the preprocessing function to the dataset object.

# %%
prep_train_ds = train_ds.map(lambda x, y: (vgg16.preprocess_input(x), y))
prep_val_ds = val_ds.map(lambda x, y: (vgg16.preprocess_input(x), y))
prep_test_ds = test_ds.map(lambda x, y: (vgg16.preprocess_input(x), y))

# %% [markdown]
# ### Compile and Fit the model

# %%
vgg16_model.compile(
    optimizer=Adam(learning_rate=learning_rate),
    loss=BinaryCrossentropy(),
    metrics=[BinaryAccuracy(name='accuracy')]
)

history = vgg16_model.fit(
    prep_train_ds,
    validation_data=prep_val_ds,
    epochs=epochs,
    callbacks=[
        ModelCheckpoint('vgg16_model-halfTL.keras', monitor=monitor_metric, save_weights_only=False, save_best_only=True, verbose=1),
    ],
)
# Out:
# Epoch 1/30
# 25/25 [==============================] - ETA: 0s - loss: 0.8415 - accuracy: 0.8542
# Epoch 1: val_loss improved from inf to 1.19936, saving model to vgg16_model-halfTL.keras
# 25/25 [==============================] - 4s 136ms/step - loss: 0.8415 - accuracy: 0.8542 - val_loss: 1.1994 - val_accuracy: 0.7642
# Epoch 2/30
# 25/25 [==============================] - ETA: 0s - loss: 0.0206 - accuracy: 0.9949
# Epoch 2: val_loss did not improve from 1.19936
# 25/25 [==============================] - 3s 117ms/step - loss: 0.0206 - accuracy: 0.9949 - val_loss: 1.5021 - val_accuracy: 0.7830
# Epoch 3/30
# 25/25 [==============================] - ETA: 0s - loss: 0.0045 - accuracy: 0.9974
# Epoch 3: val_loss improved from 1.19936 to 0.80134, saving model to vgg16_model-halfTL.keras
# 25/25 [==============================] - 5s 210ms/step - loss: 0.0045 - accuracy: 0.9974 - val_loss: 0.8013 - val_accuracy: 0.8774
# Epoch 4/30
# 25/25 [==============================] - ETA: 0s - loss: 0.0058 - accuracy: 0.9987
# Epoch 4: val_loss did not improve from 0.80134
# 25/25 [==============================] - 3s 116ms/step - loss: 0.0058 - accuracy: 0.9987 - val_loss: 1.7758 - val_accuracy: 0.7642
# Epoch 5/30
# 25/25 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 1.0000
# Epoch 5: val_loss did not improve from 0.80134
# 25/25 [==============================] - 3s 115ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 1.3807 - val_accuracy: 0.8302
# Epoch 6/30
# 24/25 [===========================>..] - ETA: 0s - loss: 1.4448e-04 - accuracy: 1.0000
# Epoch 6: val_loss did not improve from 0.80134
# 25/25 [==============================] - 3s 117ms/step - loss: 1.4387e-04 - accuracy: 1.0000 - val_loss: 0.8797 - val_accuracy: 0.8774
# Epoch 7/30
# 25/25 [==============================] - ETA: 0s - loss: 1.0979e-04 - accuracy: 1.0000
# Epoch 7: val_loss did not improve from 0.80134
# 25/25 [==============================] - 3s 116ms/step - loss: 1.0979e-04 - accuracy: 1.0000 - val_loss: 0.9055 - val_accuracy: 0.8679
# Epoch 8/30
# 25/25 [==============================] - ETA: 0s - loss: 6.7868e-05 - accuracy: 1.0000
# Epoch 8: val_loss did not improve from 0.80134
# 25/25 [==============================] - 3s 117ms/step - loss: 6.7868e-05 - accuracy: 1.0000 - val_loss: 0.9403 - val_accuracy: 0.8679
# Epoch 9/30
# 25/25 [==============================] - ETA: 0s - loss: 4.8112e-05 - accuracy: 1.0000
# Epoch 9: val_loss did not improve from 0.80134
# 25/25 [==============================] - 3s 116ms/step - loss: 4.8112e-05 - accuracy: 1.0000 - val_loss: 0.9639 - val_accuracy: 0.8679
# Epoch 10/30
# 25/25 [==============================] - ETA: 0s - loss: 3.9068e-05 - accuracy: 1.0000
# Epoch 10: val_loss did not improve from 0.80134
# 25/25 [==============================] - 3s 117ms/step - loss: 3.9068e-05 - accuracy: 1.0000 - val_loss: 0.9831 - val_accuracy: 0.8679
# Epoch 11/30
# 25/25 [==============================] - ETA: 0s - loss: 3.3604e-05 - accuracy: 1.0000
# Epoch 11: val_loss did not improve from 0.80134
# 25/25 [==============================] - 3s 117ms/step - loss: 3.3604e-05 - accuracy: 1.0000 - val_loss: 1.0002 - val_accuracy: 0.8774
# Epoch 12/30
# 25/25 [==============================] - ETA: 0s - loss: 2.9427e-05 - accuracy: 1.0000
# Epoch 12: val_loss did not improve from 0.80134
# 25/25 [==============================] - 3s 117ms/step - loss: 2.9427e-05 - accuracy: 1.0000 - val_loss: 1.0149 - val_accuracy: 0.8774
# Epoch 13/30
# 25/25 [==============================] - ETA: 0s - loss: 2.6281e-05 - accuracy: 1.0000
# Epoch 13: val_loss did not improve from 0.80134
# 25/25 [==============================] - 3s 117ms/step - loss: 2.6281e-05 - accuracy: 1.0000 - val_loss: 1.0262 - val_accuracy: 0.8774
# Epoch 14/30
# 25/25 [==============================] - ETA: 0s - loss: 2.3924e-05 - accuracy: 1.0000
# Epoch 14: val_loss did not improve from 0.80134
# 25/25 [==============================] - 3s 116ms/step - loss: 2.3924e-05 - accuracy: 1.0000 - val_loss: 1.0388 - val_accuracy: 0.8679
# Epoch 15/30
# 25/25 [==============================] - ETA: 0s - loss: 2.1808e-05 - accuracy: 1.0000
# Epoch 15: val_loss did not improve from 0.80134
# 25/25 [==============================] - 3s 117ms/step - loss: 2.1808e-05 - accuracy: 1.0000 - val_loss: 1.0492 - val_accuracy: 0.8679
# Epoch 16/30
# 25/25 [==============================] - ETA: 0s - loss: 2.0125e-05 - accuracy: 1.0000
# Epoch 16: val_loss did not improve from 0.80134
# 25/25 [==============================] - 3s 116ms/step - loss: 2.0125e-05 - accuracy: 1.0000 - val_loss: 1.0580 - val_accuracy: 0.8679
# Epoch 17/30
# 25/25 [==============================] - ETA: 0s - loss: 1.8777e-05 - accuracy: 1.0000
# Epoch 17: val_loss did not improve from 0.80134
# 25/25 [==============================] - 3s 117ms/step - loss: 1.8777e-05 - accuracy: 1.0000 - val_loss: 1.0665 - val_accuracy: 0.8679
# Epoch 18/30
# 25/25 [==============================] - ETA: 0s - loss: 1.7535e-05 - accuracy: 1.0000
# Epoch 18: val_loss did not improve from 0.80134
# 25/25 [==============================] - 3s 118ms/step - loss: 1.7535e-05 - accuracy: 1.0000 - val_loss: 1.0742 - val_accuracy: 0.8679
# Epoch 19/30
# 25/25 [==============================] - ETA: 0s - loss: 1.6537e-05 - accuracy: 1.0000
# Epoch 19: val_loss did not improve from 0.80134
# 25/25 [==============================] - 3s 116ms/step - loss: 1.6537e-05 - accuracy: 1.0000 - val_loss: 1.0807 - val_accuracy: 0.8679
# Epoch 20/30
# 25/25 [==============================] - ETA: 0s - loss: 1.5534e-05 - accuracy: 1.0000
# Epoch 20: val_loss did not improve from 0.80134
# 25/25 [==============================] - 3s 117ms/step - loss: 1.5534e-05 - accuracy: 1.0000 - val_loss: 1.0879 - val_accuracy: 0.8679
# Epoch 21/30
# 25/25 [==============================] - ETA: 0s - loss: 1.4658e-05 - accuracy: 1.0000
# Epoch 21: val_loss did not improve from 0.80134
# 25/25 [==============================] - 3s 117ms/step - loss: 1.4658e-05 - accuracy: 1.0000 - val_loss: 1.0935 - val_accuracy: 0.8679
# Epoch 22/30
# 25/25 [==============================] - ETA: 0s - loss: 1.3908e-05 - accuracy: 1.0000
# Epoch 22: val_loss did not improve from 0.80134
# 25/25 [==============================] - 3s 116ms/step - loss: 1.3908e-05 - accuracy: 1.0000 - val_loss: 1.0989 - val_accuracy: 0.8679
# Epoch 23/30
# 25/25 [==============================] - ETA: 0s - loss: 1.3251e-05 - accuracy: 1.0000
# Epoch 23: val_loss did not improve from 0.80134
# 25/25 [==============================] - 3s 116ms/step - loss: 1.3251e-05 - accuracy: 1.0000 - val_loss: 1.1048 - val_accuracy: 0.8679
# Epoch 24/30
# 25/25 [==============================] - ETA: 0s - loss: 1.2545e-05 - accuracy: 1.0000
# Epoch 24: val_loss did not improve from 0.80134
# 25/25 [==============================] - 3s 117ms/step - loss: 1.2545e-05 - accuracy: 1.0000 - val_loss: 1.1105 - val_accuracy: 0.8679
# Epoch 25/30
# 25/25 [==============================] - ETA: 0s - loss: 1.1998e-05 - accuracy: 1.0000
# Epoch 25: val_loss did not improve from 0.80134
# 25/25 [==============================] - 3s 118ms/step - loss: 1.1998e-05 - accuracy: 1.0000 - val_loss: 1.1147 - val_accuracy: 0.8679
# Epoch 26/30
# 25/25 [==============================] - ETA: 0s - loss: 1.1421e-05 - accuracy: 1.0000
# Epoch 26: val_loss did not improve from 0.80134
# 25/25 [==============================] - 3s 117ms/step - loss: 1.1421e-05 - accuracy: 1.0000 - val_loss: 1.1192 - val_accuracy: 0.8679
# Epoch 27/30
# 25/25 [==============================] - ETA: 0s - loss: 1.0936e-05 - accuracy: 1.0000
# Epoch 27: val_loss did not improve from 0.80134
# 25/25 [==============================] - 3s 115ms/step - loss: 1.0936e-05 - accuracy: 1.0000 - val_loss: 1.1231 - val_accuracy: 0.8679
# Epoch 28/30
# 25/25 [==============================] - ETA: 0s - loss: 1.0488e-05 - accuracy: 1.0000
# Epoch 28: val_loss did not improve from 0.80134
# 25/25 [==============================] - 3s 117ms/step - loss: 1.0488e-05 - accuracy: 1.0000 - val_loss: 1.1267 - val_accuracy: 0.8679
# Epoch 29/30
# 25/25 [==============================] - ETA: 0s - loss: 1.0048e-05 - accuracy: 1.0000
# Epoch 29: val_loss did not improve from 0.80134
# 25/25 [==============================] - 3s 117ms/step - loss: 1.0048e-05 - accuracy: 1.0000 - val_loss: 1.1301 - val_accuracy: 0.8679
# Epoch 30/30
# 25/25 [==============================] - ETA: 0s - loss: 9.6618e-06 - accuracy: 1.0000
# Epoch 30: val_loss did not improve from 0.80134
# 25/25 [==============================] - 3s 116ms/step - loss: 9.6618e-06 - accuracy: 1.0000 - val_loss: 1.1329 - val_accuracy: 0.8679

# %% [markdown]
# ### Plot loss and accuracy graphs

# %%
plt.figure(figsize=(16, 6))
plt.subplot(1,2,1)
plt.plot(history.history['loss'], '.-')
plt.plot(history.history['val_loss'], '.-')
plt.xlabel('Epoch', fontsize=20)
plt.xticks(fontsize=16)
plt.ylabel('Loss Value',fontsize=20)
plt.yticks(fontsize=16)
plt.legend(['loss', 'val_loss'],fontsize=16)

plt.subplot(1,2,2)
plt.plot(history.history['accuracy'], '.-')
plt.plot(history.history['val_accuracy'], '.-')
plt.xlabel('Epoch',fontsize=20)
plt.xticks(fontsize=16)
plt.ylabel('Accuracy',fontsize=20)
plt.yticks(fontsize=16)
plt.ylim([0, 1.1])
plt.legend(['accuracy', 'val_accuracy'],fontsize=16)

plt.show()

# %% [markdown]
# ### Load the best checkpoint and evaluate the model using the test dataset

# %%
vgg16_model = keras.models.load_model('vgg16_model-halfTL.keras')

vgg16_model.compile(
    optimizer=Adam(learning_rate=learning_rate),
    loss=BinaryCrossentropy(),
    metrics=[
        BinaryAccuracy(name='accuracy'),
        Precision(name='precision'),
        Recall(name='recall'),
        F1Score(name='f1score'),
    ]
)

eval = vgg16_model.evaluate(prep_test_ds, return_dict=True)

eval
# Out:
# 5/5 [==============================] - 1s 111ms/step - loss: 1.4981 - accuracy: 0.7875 - precision: 0.8871 - recall: 0.6707 - f1score: 0.7074
# {'loss': 1.4980989694595337,
#  'accuracy': 0.7875000238418579,
#  'precision': 0.8870967626571655,
#  'recall': 0.6707317233085632,
#  'f1score': array([0.70742357], dtype=float32)}

# %% [markdown]
# ## Unfreeze all the layers
# Now, we unfreeze all the layers and compile and train the model again using the training dataset.

# %%
for layer in vgg16_model.layers:
  layer.trainable = True
vgg16_model.summary(show_trainable=True)
# Out:
# Model: "VGG16_Model_TL"
# ____________________________________________________________________________
#  Layer (type)                Output Shape              Param #   Trainable
# ============================================================================
#  input_2 (InputLayer)        [(None, 256, 256, 3)]     0         Y
#
#  block1_conv1 (Conv2D)       (None, 256, 256, 64)      1792      Y
#
#  block1_conv2 (Conv2D)       (None, 256, 256, 64)      36928     Y
#
#  block1_pool (MaxPooling2D)  (None, 128, 128, 64)      0         Y
#
#  block2_conv1 (Conv2D)       (None, 128, 128, 128)     73856     Y
#
#  block2_conv2 (Conv2D)       (None, 128, 128, 128)     147584    Y
#
#  block2_pool (MaxPooling2D)  (None, 64, 64, 128)       0         Y
#
#  block3_conv1 (Conv2D)       (None, 64, 64, 256)       295168    Y
#
#  block3_conv2 (Conv2D)       (None, 64, 64, 256)       590080    Y
#
#  block3_conv3 (Conv2D)       (None, 64, 64, 256)       590080    Y
#
#  block3_pool (MaxPooling2D)  (None, 32, 32, 256)       0         Y
#
#  block4_conv1 (Conv2D)       (None, 32, 32, 512)       1180160   Y
#
#  block4_conv2 (Conv2D)       (None, 32, 32, 512)       2359808   Y
#
#  block4_conv3 (Conv2D)       (None, 32, 32, 512)       2359808   Y
#
#  block4_pool (MaxPooling2D)  (None, 16, 16, 512)       0         Y
#
#  block5_conv1 (Conv2D)       (None, 16, 16, 512)       2359808   Y
#
#  block5_conv2 (Conv2D)       (None, 16, 16, 512)       2359808   Y
#
#  block5_conv3 (Conv2D)       (None, 16, 16, 512)       2359808   Y
#
#  block5_pool (MaxPooling2D)  (None, 8, 8, 512)         0         Y
#
#  flatten_1 (Flatten)         (None, 32768)             0         Y
#
#  dense_3 (Dense)             (None, 256)               8388864   Y
#
#  dense_4 (Dense)             (None, 128)               32896     Y
#
#  dense_5 (Dense)             (None, 1)                 129       Y
#
# ============================================================================
# Total params: 23136577 (88.26 MB)
# Trainable params: 23136577 (88.26 MB)
# Non-trainable params: 0 (0.00 Byte)
# ____________________________________________________________________________

# %% [markdown]
# ### Compile and Fit the Model

# %%
vgg16_model.compile(
    optimizer=Adam(learning_rate=learning_rate),
    loss=BinaryCrossentropy(),
    metrics=[BinaryAccuracy(name='accuracy')]
)

history = vgg16_model.fit(
    prep_train_ds,
    validation_data=prep_val_ds,
    epochs=epochs,
    callbacks=[
        ModelCheckpoint('vgg16_model-fullTL.keras', monitor=monitor_metric, save_weights_only=False, save_best_only=True, verbose=1),
    ],
)
# Out:
# Epoch 1/30
# 25/25 [==============================] - ETA: 0s - loss: 0.9596 - accuracy: 0.7532
# Epoch 1: val_loss improved from inf to 0.76223, saving model to vgg16_model-fullTL.keras
# 25/25 [==============================] - 25s 899ms/step - loss: 0.9596 - accuracy: 0.7532 - val_loss: 0.7622 - val_accuracy: 0.7358
# Epoch 2/30
# 25/25 [==============================] - ETA: 0s - loss: 0.3163 - accuracy: 0.8760
# Epoch 2: val_loss improved from 0.76223 to 0.54037, saving model to vgg16_model-fullTL.keras
# 25/25 [==============================] - 14s 583ms/step - loss: 0.3163 - accuracy: 0.8760 - val_loss: 0.5404 - val_accuracy: 0.7830
# Epoch 3/30
# 25/25 [==============================] - ETA: 0s - loss: 0.1313 - accuracy: 0.9501
# Epoch 3: val_loss did not improve from 0.54037
# 25/25 [==============================] - 7s 271ms/step - loss: 0.1313 - accuracy: 0.9501 - val_loss: 0.7416 - val_accuracy: 0.8208
# Epoch 4/30
# 25/25 [==============================] - ETA: 0s - loss: 0.0545 - accuracy: 0.9744
# Epoch 4: val_loss improved from 0.54037 to 0.46960, saving model to vgg16_model-fullTL.keras
# 25/25 [==============================] - 20s 812ms/step - loss: 0.0545 - accuracy: 0.9744 - val_loss: 0.4696 - val_accuracy: 0.8868
# Epoch 5/30
# 25/25 [==============================] - ETA: 0s - loss: 0.0436 - accuracy: 0.9872
# Epoch 5: val_loss did not improve from 0.46960
# 25/25 [==============================] - 7s 270ms/step - loss: 0.0436 - accuracy: 0.9872 - val_loss: 0.4869 - val_accuracy: 0.8491
# Epoch 6/30
# 25/25 [==============================] - ETA: 0s - loss: 0.0568 - accuracy: 0.9783
# Epoch 6: val_loss did not improve from 0.46960
# 25/25 [==============================] - 7s 267ms/step - loss: 0.0568 - accuracy: 0.9783 - val_loss: 0.5174 - val_accuracy: 0.8679
# Epoch 7/30
# 25/25 [==============================] - ETA: 0s - loss: 0.0426 - accuracy: 0.9872
# Epoch 7: val_loss did not improve from 0.46960
# 25/25 [==============================] - 7s 275ms/step - loss: 0.0426 - accuracy: 0.9872 - val_loss: 0.7119 - val_accuracy: 0.8868
# Epoch 8/30
# 25/25 [==============================] - ETA: 0s - loss: 0.0247 - accuracy: 0.9962
# Epoch 8: val_loss did not improve from 0.46960
# 25/25 [==============================] - 7s 277ms/step - loss: 0.0247 - accuracy: 0.9962 - val_loss: 0.5140 - val_accuracy: 0.8302
# Epoch 9/30
# 25/25 [==============================] - ETA: 0s - loss: 0.0193 - accuracy: 0.9936
# Epoch 9: val_loss did not improve from 0.46960
# 25/25 [==============================] - 7s 278ms/step - loss: 0.0193 - accuracy: 0.9936 - val_loss: 1.1266 - val_accuracy: 0.8302
# Epoch 10/30
# 25/25 [==============================] - ETA: 0s - loss: 0.1935 - accuracy: 0.9425
# Epoch 10: val_loss did not improve from 0.46960
# 25/25 [==============================] - 7s 274ms/step - loss: 0.1935 - accuracy: 0.9425 - val_loss: 1.1687 - val_accuracy: 0.7358
# Epoch 11/30
# 25/25 [==============================] - ETA: 0s - loss: 0.3052 - accuracy: 0.8811
# Epoch 11: val_loss did not improve from 0.46960
# 25/25 [==============================] - 7s 274ms/step - loss: 0.3052 - accuracy: 0.8811 - val_loss: 0.6153 - val_accuracy: 0.8208
# Epoch 12/30
# 25/25 [==============================] - ETA: 0s - loss: 0.0878 - accuracy: 0.9668
# Epoch 12: val_loss did not improve from 0.46960
# 25/25 [==============================] - 7s 270ms/step - loss: 0.0878 - accuracy: 0.9668 - val_loss: 0.6213 - val_accuracy: 0.8396
# Epoch 13/30
# 25/25 [==============================] - ETA: 0s - loss: 0.0779 - accuracy: 0.9706
# Epoch 13: val_loss did not improve from 0.46960
# 25/25 [==============================] - 7s 274ms/step - loss: 0.0779 - accuracy: 0.9706 - val_loss: 0.9753 - val_accuracy: 0.8396
# Epoch 14/30
# 25/25 [==============================] - ETA: 0s - loss: 0.0095 - accuracy: 0.9987
# Epoch 14: val_loss did not improve from 0.46960
# 25/25 [==============================] - 7s 277ms/step - loss: 0.0095 - accuracy: 0.9987 - val_loss: 1.3718 - val_accuracy: 0.8868
# Epoch 15/30
# 25/25 [==============================] - ETA: 0s - loss: 0.0310 - accuracy: 0.9936
# Epoch 15: val_loss did not improve from 0.46960
# 25/25 [==============================] - 7s 267ms/step - loss: 0.0310 - accuracy: 0.9936 - val_loss: 0.8663 - val_accuracy: 0.7830
# Epoch 16/30
# 25/25 [==============================] - ETA: 0s - loss: 0.0277 - accuracy: 0.9923
# Epoch 16: val_loss did not improve from 0.46960
# 25/25 [==============================] - 7s 268ms/step - loss: 0.0277 - accuracy: 0.9923 - val_loss: 1.5121 - val_accuracy: 0.8585
# Epoch 17/30
# 25/25 [==============================] - ETA: 0s - loss: 0.0073 - accuracy: 0.9974
# Epoch 17: val_loss did not improve from 0.46960
# 25/25 [==============================] - 7s 268ms/step - loss: 0.0073 - accuracy: 0.9974 - val_loss: 0.9481 - val_accuracy: 0.8679
# Epoch 18/30
# 25/25 [==============================] - ETA: 0s - loss: 0.0026 - accuracy: 0.9987
# Epoch 18: val_loss did not improve from 0.46960
# 25/25 [==============================] - 7s 267ms/step - loss: 0.0026 - accuracy: 0.9987 - val_loss: 1.7234 - val_accuracy: 0.8302
# Epoch 19/30
# 25/25 [==============================] - ETA: 0s - loss: 0.0106 - accuracy: 0.9949
# Epoch 19: val_loss did not improve from 0.46960
# 25/25 [==============================] - 7s 278ms/step - loss: 0.0106 - accuracy: 0.9949 - val_loss: 1.4250 - val_accuracy: 0.8302
# Epoch 20/30
# 25/25 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 0.9987
# Epoch 20: val_loss did not improve from 0.46960
# 25/25 [==============================] - 7s 274ms/step - loss: 0.0019 - accuracy: 0.9987 - val_loss: 0.7782 - val_accuracy: 0.8962
# Epoch 21/30
# 25/25 [==============================] - ETA: 0s - loss: 0.0040 - accuracy: 0.9987
# Epoch 21: val_loss did not improve from 0.46960
# 25/25 [==============================] - 7s 267ms/step - loss: 0.0040 - accuracy: 0.9987 - val_loss: 0.8848 - val_accuracy: 0.8679
# Epoch 22/30
# 25/25 [==============================] - ETA: 0s - loss: 0.0077 - accuracy: 0.9949
# Epoch 22: val_loss did not improve from 0.46960
# 25/25 [==============================] - 7s 268ms/step - loss: 0.0077 - accuracy: 0.9949 - val_loss: 1.0536 - val_accuracy: 0.8302
# Epoch 23/30
# 25/25 [==============================] - ETA: 0s - loss: 0.0041 - accuracy: 0.9987
# Epoch 23: val_loss did not improve from 0.46960
# 25/25 [==============================] - 7s 270ms/step - loss: 0.0041 - accuracy: 0.9987 - val_loss: 1.4163 - val_accuracy: 0.8868
# Epoch 24/30
# 25/25 [==============================] - ETA: 0s - loss: 0.0079 - accuracy: 0.9962
# Epoch 24: val_loss did not improve from 0.46960
# 25/25 [==============================] - 7s 274ms/step - loss: 0.0079 - accuracy: 0.9962 - val_loss: 1.4537 - val_accuracy: 0.8585
# Epoch 25/30
# 25/25 [==============================] - ETA: 0s - loss: 0.0848 - accuracy: 0.9744
# Epoch 25: val_loss did not improve from 0.46960
# 25/25 [==============================] - 7s 278ms/step - loss: 0.0848 - accuracy: 0.9744 - val_loss: 0.5699 - val_accuracy: 0.8774
# Epoch 26/30
# 25/25 [==============================] - ETA: 0s - loss: 0.0852 - accuracy: 0.9744
# Epoch 26: val_loss did not improve from 0.46960
# 25/25 [==============================] - 7s 278ms/step - loss: 0.0852 - accuracy: 0.9744 - val_loss: 0.8036 - val_accuracy: 0.8396
# Epoch 27/30
# 25/25 [==============================] - ETA: 0s - loss: 0.0527 - accuracy: 0.9783
# Epoch 27: val_loss did not improve from 0.46960
# 25/25 [==============================] - 7s 278ms/step - loss: 0.0527 - accuracy: 0.9783 - val_loss: 1.4526 - val_accuracy: 0.8396
# Epoch 28/30
# 25/25 [==============================] - ETA: 0s - loss: 0.0238 - accuracy: 0.9898
# Epoch 28: val_loss improved from 0.46960 to 0.34953, saving model to vgg16_model-fullTL.keras
# 25/25 [==============================] - 12s 502ms/step - loss: 0.0238 - accuracy: 0.9898 - val_loss: 0.3495 - val_accuracy: 0.8774
# Epoch 29/30
# 25/25 [==============================] - ETA: 0s - loss: 0.0159 - accuracy: 0.9962
# Epoch 29: val_loss did not improve from 0.34953
# 25/25 [==============================] - 7s 278ms/step - loss: 0.0159 - accuracy: 0.9962 - val_loss: 0.6714 - val_accuracy: 0.8962
# Epoch 30/30
# 25/25 [==============================] - ETA: 0s - loss: 0.0027 - accuracy: 0.9987
# Epoch 30: val_loss did not improve from 0.34953
# 25/25 [==============================] - 7s 276ms/step - loss: 0.0027 - accuracy: 0.9987 - val_loss: 0.9288 - val_accuracy: 0.8774

# %% [markdown]
# ### Plotting loss and accuracy graphs

# %%
plt.figure(figsize=(16, 6))
plt.subplot(1,2,1)
plt.plot(history.history['loss'], '.-')
plt.plot(history.history['val_loss'], '.-')
plt.xlabel('Epoch', fontsize=20)
plt.xticks(fontsize=16)
plt.ylabel('Loss Value',fontsize=20)
plt.yticks(fontsize=16)
plt.legend(['loss', 'val_loss'],fontsize=16)

plt.subplot(1,2,2)
plt.plot(history.history['accuracy'], '.-')
plt.plot(history.history['val_accuracy'], '.-')
plt.xlabel('Epoch',fontsize=20)
plt.xticks(fontsize=16)
plt.ylabel('Accuracy',fontsize=20)
plt.yticks(fontsize=16)
plt.ylim([0, 1.1])
plt.legend(['accuracy', 'val_accuracy'],fontsize=16)

# plt.savefig("./{}.eps".format('vgg-c-2'), bbox_inches='tight', format='eps', dpi=1000)
plt.show()

# %% [markdown]
# ### Load the best checkpoint and evaluate the model using the test dataset

# %%
vgg16_model = keras.models.load_model('vgg16_model-fullTL.keras')

vgg16_model.compile(
    optimizer=Adam(learning_rate=learning_rate),
    loss=BinaryCrossentropy(),
    metrics=[
        BinaryAccuracy(name='accuracy'),
        Precision(name='precision'),
        Recall(name='recall'),
        F1Score(name='f1score'),
    ]
)

eval = vgg16_model.evaluate(prep_test_ds, return_dict=True)

eval
# Out:
# 5/5 [==============================] - 1s 111ms/step - loss: 0.8590 - accuracy: 0.7688 - precision: 0.8000 - recall: 0.7317 - f1score: 0.7039
# {'loss': 0.8589662313461304,
#  'accuracy': 0.768750011920929,
#  'precision': 0.800000011920929,
#  'recall': 0.7317073345184326,
#  'f1score': array([0.70386267], dtype=float32)}
